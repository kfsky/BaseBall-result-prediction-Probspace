# %%
emp = "exp_5_"

# %%
import numpy as np 
import pandas as pd 
import re
import typing as tp

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import string
import lightgbm as lgb
import xgboost as xgb
from tqdm import tqdm

import os
from glob import glob

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics

from collections import Counter
pd.set_option('display.max_columns', 100)
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']


import category_encoders as ce
from sklearn.model_selection import KFold, StratifiedKFold

from xfeat import (SelectCategorical, LabelEncoder, Pipeline, ConcatCombination, SelectNumerical, 
                   ArithmeticCombinations, TargetEncoder, aggregation, GBDTFeatureSelector, GBDTFeatureExplorer)

import warnings

# %%
train_df = pd.read_csv("../train_data.csv")
test_df = pd.read_csv("../test_data.csv")
game_df = pd.read_csv("../game_info.csv")
game_df = game_df.drop('Unnamed: 0',axis=1)

# bool型が面倒なので、先に変換する
bool_list = ["b1", "b2", "b3"]
for i in bool_list:
    train_df[i] = train_df[i]*1
    test_df[i] = test_df[i]*1

# baselineとして、train_dfにしかないデータは削除する。
# 実験のどこかで追加できるように前処理をかける
drop_list = [
    "pitchType", "speed", "ballPositionLabel", "ballX",
    "ballY", "dir", "dist", "battingType", "isOuts"
]
train_df = train_df.drop(drop_list, axis=1)

print('before')
print(train_df.shape)
print(test_df.shape)

# game_infoをmerge
train_df = pd.merge(train_df, game_df, on='gameID', how='left')
test_df = pd.merge(test_df, game_df, on='gameID', how='left')

print('after')
print(train_df.shape)
print(test_df.shape)
# Out:
# before
# (20400, 15)
# (33808, 14)
# after
# (20400, 22)
# (33808, 21)

# %%
from contextlib import contextmanager
from time import time

@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)

# %%
# 前処理前の準備として実施する
train_df["counts"] = train_df[['S', 'B']].apply(lambda x: '{}-{}'.format(x[0], x[1]),axis=1)
test_df["counts"] = test_df[['S', 'B']].apply(lambda x: '{}-{}'.format(x[0], x[1]),axis=1)

# exp4との差
train_df["total_counts"] = train_df[['S', 'B', 'O']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]),axis=1)
test_df["total_counts"] = test_df[['S', 'B', 'O']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]),axis=1)

# %%
# baseBlock 

class BaseBlock(object):
    def fit(self, input_df, y=None):
        return self.transform(input_df)
    
    def transform(self, input_df):
        raise NotImplementedError()
        
# CountEncoding
class CountEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        self.encoder = ce.CountEncoder()
        self.encoder.fit(input_df[self.cols])
        return self.encoder.transform(input_df[self.cols]).add_prefix("CE_")
    
# OneHotEncoding
class OneHotEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        self.encoder = ce.OneHotEncoder(use_cat_names=True)
        self.encoder.fit(input_df[self.cols])
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        return self.encoder.transform(input_df[self.cols]).add_prefix("OHE_")

# OrdinalEncoding
class OrdinalEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        self.encoder = ce.OrdinalEncoder()
        self.encoder.fit(input_df[self.cols])
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        return self.encoder.transform(input_df[self.cols]).add_prefix("OE_")

# %%
# 前処理の追加をする関数
def get_top_bottom(x):
    if '表' in x:
        return 0
    else:
        return 1

def get_inning(input_df):
    output_df = pd.DataFrame()
    
    output_df['top_bottom'] = input_df['inning'].apply(lambda x: get_top_bottom(x))
    output_df['inning_num'] = input_df['inning'].apply(lambda x: re.sub("\\D", "", x))
    
    return output_df

# ピッチャー左対バッター右
def left_vs_right(x, y):
    if x=="L" and y=='R':
        return 1
    else:
        return 0

def right_vs_left(x,y):
    if x=='R' and y=='L':
        return 1
    else:
        return 0

def get_pvsb(input_df):
    output_df = pd.DataFrame()
    output_df['left_right'] = input_df[['pitcherHand', 'batterHand']].apply(lambda x: left_vs_right(x[0], x[1]),axis=1)
    output_df['right_left'] = input_df[['pitcherHand', 'batterHand']].apply(lambda x: right_vs_left(x[0], x[1]),axis=1)
    
    return output_df

# %%
# encoding系の処理を行う関数
def get_ce_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    
    cols = [
        'pitcher',
        'pitcherHand',
        'batter',
        'batterHand',
        'bottomTeam',
        'topTeam',
        'place',
        'inning',
        'counts',
        'total_counts'
    ]
    
    encoder = CountEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df.astype(str))
    return output_df

def get_oe_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
        'pitcher',
        'pitcherHand',
        'batter',
        'batterHand',
        'bottomTeam',
        'topTeam',
        'place',
        'inning',
        'counts',
        'total_counts'
    ]
    encoder = OrdinalEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df)
    return output_df

def get_ohe_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
       'pitcher',
        'pitcherHand',
        'batter',
        'batterHand',
        'bottomTeam',
        'topTeam',
        'place',
        'inning',
        'counts',
        'total_counts'
    ]
    encoder = OneHotEncodingBlock(cols=cols)
    output_df = encoder.fit(_input_df)
    return output_df


# numeric_feature
def create_numeric_feature(input_df):
    use_columns = [
        'totalPitchingCount',
        'B', 'S', 'O','b1', 'b2', 'b3',
    ]

    return input_df[use_columns].copy()

# %%
# 前処理関数を順々に処理していく関数
def to_features(train, test):
    input_df = pd.concat([train, test]).reset_index(drop=True)

    processes = [
        get_oe_features,
        get_ce_features,
        get_ohe_features,
        create_numeric_feature,
        get_inning,
        get_pvsb
    ]

    output_df = pd.DataFrame()
    for func in tqdm(processes):
        _df = func(input_df)
        assert len(_df) == len(input_df), func.__name__
        output_df = pd.concat([output_df, _df], axis=1)

    train_x = output_df.iloc[:len(train)] 
    test_x = output_df.iloc[len(train):].reset_index(drop=True)
    return train_x, test_x

# %%
target_data = "y" 

train_x, test_x = to_features(train_df, test_df)
train_ys_for_split = train_df[target_data]
train_ys = train_df[target_data].values
# Out:
#  33%|███▎      | 2/6 [00:00<00:01,  3.17it/s]/home/kengo-fujii/anaconda3/envs/py36/lib/python3.6/site-packages/category_encoders/utils.py:21: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# 100%|██████████| 6/6 [00:04<00:00,  1.22it/s]

# %%
def fit_lgbm(X, y, cv, params: dict=None, verbose: int=50):
    """lightGBM を CrossValidation の枠組みで学習を行なう function"""
    metric_func = f1_score

    # パラメータがないときは、空の dict で置き換える
    if params is None:
        params = {}

    models = []
    # training data の target と同じだけのゼロ配列を用意
    # float にしないと悲しい事件が起こるのでそこだけ注意
    oof_pred = np.zeros_like(y, dtype=np.float)

    for i, (idx_train, idx_valid) in enumerate(cv): 
        # この部分が交差検証のところです。データセットを cv instance によって分割します
        # training data を trian/valid に分割
        x_train, y_train = X[idx_train], y[idx_train]
        x_valid, y_valid = X[idx_valid], y[idx_valid]

        clf = lgb.LGBMClassifier(**params)

        with timer(prefix='fit fold={} '.format(i + 1)):
            clf.fit(x_train, y_train, 
                    eval_set=[(x_valid, y_valid)],  
                    early_stopping_rounds=verbose,
                    verbose=verbose)

        pred_i = clf.predict(x_valid)

        oof_pred[idx_valid] = pred_i
        models.append(clf)

        print(f'Fold {i} Macro-F1: {metric_func(y_valid, pred_i, average="macro") :.4f}')

    score = metric_func(y, oof_pred, average="macro") 
    print('FINISHED | Whole Macro-F1: {:.4f}'.format(score))
    return oof_pred, models

# %%
lgm_params = {  
    "n_estimators": 20000,
    "objective": 'multiclass',
    "num_class":8,
    "learning_rate": 0.01,
    "num_leaves": 36,
    "random_state": 2021,
    "n_jobs": -1,
    "importance_type": "gain",
    'colsample_bytree': .5,
    "reg_lambda": 5,
    "max_depth":7,
    }

fold = KFold(n_splits=5, shuffle=True, random_state=42)
cv = list(fold.split(train_x, train_ys)) # もともとが generator なため明示的に list に変換する

# %%
oof, models = fit_lgbm(train_x.values, train_ys, cv, params=lgm_params)
# Out:
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.47903
# [100]	valid_0's multi_logloss: 1.46228
# [150]	valid_0's multi_logloss: 1.4535
# [200]	valid_0's multi_logloss: 1.44793
# [250]	valid_0's multi_logloss: 1.44449
# [300]	valid_0's multi_logloss: 1.44203
# [350]	valid_0's multi_logloss: 1.44037
# [400]	valid_0's multi_logloss: 1.43899
# [450]	valid_0's multi_logloss: 1.43775
# [500]	valid_0's multi_logloss: 1.43633
# [550]	valid_0's multi_logloss: 1.4352
# [600]	valid_0's multi_logloss: 1.43428
# [650]	valid_0's multi_logloss: 1.43332
# [700]	valid_0's multi_logloss: 1.43253
# [750]	valid_0's multi_logloss: 1.43153
# [800]	valid_0's multi_logloss: 1.43072
# [850]	valid_0's multi_logloss: 1.42997
# [900]	valid_0's multi_logloss: 1.42944
# [950]	valid_0's multi_logloss: 1.42894
# [1000]	valid_0's multi_logloss: 1.42849
# [1050]	valid_0's multi_logloss: 1.42785
# [1100]	valid_0's multi_logloss: 1.42738
# [1150]	valid_0's multi_logloss: 1.42681
# [1200]	valid_0's multi_logloss: 1.42642
# [1250]	valid_0's multi_logloss: 1.42595
# [1300]	valid_0's multi_logloss: 1.42562
# [1350]	valid_0's multi_logloss: 1.42524
# [1400]	valid_0's multi_logloss: 1.42495
# [1450]	valid_0's multi_logloss: 1.4246
# [1500]	valid_0's multi_logloss: 1.42437
# [1550]	valid_0's multi_logloss: 1.42412
# [1600]	valid_0's multi_logloss: 1.42391
# [1650]	valid_0's multi_logloss: 1.42375
# [1700]	valid_0's multi_logloss: 1.4235
# [1750]	valid_0's multi_logloss: 1.42334
# [1800]	valid_0's multi_logloss: 1.4231
# [1850]	valid_0's multi_logloss: 1.4229
# [1900]	valid_0's multi_logloss: 1.42274
# [1950]	valid_0's multi_logloss: 1.42256
# [2000]	valid_0's multi_logloss: 1.4224
# [2050]	valid_0's multi_logloss: 1.42233
# [2100]	valid_0's multi_logloss: 1.4223
# [2150]	valid_0's multi_logloss: 1.42214
# [2200]	valid_0's multi_logloss: 1.42197
# [2250]	valid_0's multi_logloss: 1.42181
# Early stopping, best iteration is:
# [2249]	valid_0's multi_logloss: 1.4218
# fit fold=1 16.389[s]
# Fold 0 Macro-F1: 0.2364
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.45311
# [100]	valid_0's multi_logloss: 1.4373
# [150]	valid_0's multi_logloss: 1.4289
# [200]	valid_0's multi_logloss: 1.42375
# [250]	valid_0's multi_logloss: 1.42058
# [300]	valid_0's multi_logloss: 1.41838
# [350]	valid_0's multi_logloss: 1.41652
# [400]	valid_0's multi_logloss: 1.41534
# [450]	valid_0's multi_logloss: 1.41434
# [500]	valid_0's multi_logloss: 1.41347
# [550]	valid_0's multi_logloss: 1.41252
# [600]	valid_0's multi_logloss: 1.41181
# [650]	valid_0's multi_logloss: 1.41104
# [700]	valid_0's multi_logloss: 1.41034
# [750]	valid_0's multi_logloss: 1.40989
# [800]	valid_0's multi_logloss: 1.40948
# [850]	valid_0's multi_logloss: 1.40895
# [900]	valid_0's multi_logloss: 1.40851
# [950]	valid_0's multi_logloss: 1.4081
# [1000]	valid_0's multi_logloss: 1.40779
# [1050]	valid_0's multi_logloss: 1.40737
# [1100]	valid_0's multi_logloss: 1.40697
# [1150]	valid_0's multi_logloss: 1.40661
# [1200]	valid_0's multi_logloss: 1.40623
# [1250]	valid_0's multi_logloss: 1.4059
# [1300]	valid_0's multi_logloss: 1.40573
# [1350]	valid_0's multi_logloss: 1.40546
# [1400]	valid_0's multi_logloss: 1.40501
# [1450]	valid_0's multi_logloss: 1.40462
# [1500]	valid_0's multi_logloss: 1.40419
# [1550]	valid_0's multi_logloss: 1.40384
# [1600]	valid_0's multi_logloss: 1.40353
# [1650]	valid_0's multi_logloss: 1.4032
# [1700]	valid_0's multi_logloss: 1.40286
# [1750]	valid_0's multi_logloss: 1.40262
# [1800]	valid_0's multi_logloss: 1.40225
# [1850]	valid_0's multi_logloss: 1.40191
# [1900]	valid_0's multi_logloss: 1.40161
# [1950]	valid_0's multi_logloss: 1.40136
# [2000]	valid_0's multi_logloss: 1.40116
# [2050]	valid_0's multi_logloss: 1.40103
# [2100]	valid_0's multi_logloss: 1.40086
# [2150]	valid_0's multi_logloss: 1.40057
# [2200]	valid_0's multi_logloss: 1.40041
# [2250]	valid_0's multi_logloss: 1.4003
# [2300]	valid_0's multi_logloss: 1.40006
# [2350]	valid_0's multi_logloss: 1.39986
# [2400]	valid_0's multi_logloss: 1.39985
# [2450]	valid_0's multi_logloss: 1.39972
# [2500]	valid_0's multi_logloss: 1.3995
# [2550]	valid_0's multi_logloss: 1.39926
# [2600]	valid_0's multi_logloss: 1.39914
# Early stopping, best iteration is:
# [2586]	valid_0's multi_logloss: 1.3991
# fit fold=2 18.219[s]
# Fold 1 Macro-F1: 0.2758
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46354
# [100]	valid_0's multi_logloss: 1.44722
# [150]	valid_0's multi_logloss: 1.43922
# [200]	valid_0's multi_logloss: 1.43398
# [250]	valid_0's multi_logloss: 1.43024
# [300]	valid_0's multi_logloss: 1.42821
# [350]	valid_0's multi_logloss: 1.4265
# [400]	valid_0's multi_logloss: 1.42529
# [450]	valid_0's multi_logloss: 1.42431
# [500]	valid_0's multi_logloss: 1.42367
# [550]	valid_0's multi_logloss: 1.4233
# [600]	valid_0's multi_logloss: 1.42279
# [650]	valid_0's multi_logloss: 1.4221
# [700]	valid_0's multi_logloss: 1.4215
# [750]	valid_0's multi_logloss: 1.42112
# [800]	valid_0's multi_logloss: 1.42058
# [850]	valid_0's multi_logloss: 1.42019
# [900]	valid_0's multi_logloss: 1.41973
# [950]	valid_0's multi_logloss: 1.41943
# [1000]	valid_0's multi_logloss: 1.41906
# [1050]	valid_0's multi_logloss: 1.41872
# [1100]	valid_0's multi_logloss: 1.41847
# [1150]	valid_0's multi_logloss: 1.41811
# [1200]	valid_0's multi_logloss: 1.41775
# [1250]	valid_0's multi_logloss: 1.41723
# [1300]	valid_0's multi_logloss: 1.41689
# [1350]	valid_0's multi_logloss: 1.4167
# [1400]	valid_0's multi_logloss: 1.41654
# [1450]	valid_0's multi_logloss: 1.41638
# [1500]	valid_0's multi_logloss: 1.41593
# [1550]	valid_0's multi_logloss: 1.41571
# [1600]	valid_0's multi_logloss: 1.41557
# [1650]	valid_0's multi_logloss: 1.41541
# [1700]	valid_0's multi_logloss: 1.41535
# [1750]	valid_0's multi_logloss: 1.41526
# [1800]	valid_0's multi_logloss: 1.41518
# Early stopping, best iteration is:
# [1793]	valid_0's multi_logloss: 1.41515
# fit fold=3 13.652[s]
# Fold 2 Macro-F1: 0.2421
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.47523
# [100]	valid_0's multi_logloss: 1.45841
# [150]	valid_0's multi_logloss: 1.44967
# [200]	valid_0's multi_logloss: 1.44383
# [250]	valid_0's multi_logloss: 1.43973
# [300]	valid_0's multi_logloss: 1.43727
# [350]	valid_0's multi_logloss: 1.43562
# [400]	valid_0's multi_logloss: 1.43446
# [450]	valid_0's multi_logloss: 1.43341
# [500]	valid_0's multi_logloss: 1.43244
# [550]	valid_0's multi_logloss: 1.43174
# [600]	valid_0's multi_logloss: 1.43102
# [650]	valid_0's multi_logloss: 1.43024
# [700]	valid_0's multi_logloss: 1.42963
# [750]	valid_0's multi_logloss: 1.42912
# [800]	valid_0's multi_logloss: 1.42866
# [850]	valid_0's multi_logloss: 1.42828
# [900]	valid_0's multi_logloss: 1.42793
# [950]	valid_0's multi_logloss: 1.42766
# [1000]	valid_0's multi_logloss: 1.42744
# [1050]	valid_0's multi_logloss: 1.42717
# [1100]	valid_0's multi_logloss: 1.42684
# [1150]	valid_0's multi_logloss: 1.42668
# [1200]	valid_0's multi_logloss: 1.4265
# [1250]	valid_0's multi_logloss: 1.42631
# [1300]	valid_0's multi_logloss: 1.4262
# [1350]	valid_0's multi_logloss: 1.42603
# [1400]	valid_0's multi_logloss: 1.42585
# [1450]	valid_0's multi_logloss: 1.42569
# [1500]	valid_0's multi_logloss: 1.42537
# [1550]	valid_0's multi_logloss: 1.42525
# [1600]	valid_0's multi_logloss: 1.42508
# [1650]	valid_0's multi_logloss: 1.42477
# [1700]	valid_0's multi_logloss: 1.4246
# Early stopping, best iteration is:
# [1687]	valid_0's multi_logloss: 1.42456
# fit fold=4 13.148[s]
# Fold 3 Macro-F1: 0.1911
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.44586
# [100]	valid_0's multi_logloss: 1.43065
# [150]	valid_0's multi_logloss: 1.42279
# [200]	valid_0's multi_logloss: 1.41829
# [250]	valid_0's multi_logloss: 1.41567
# [300]	valid_0's multi_logloss: 1.41397
# [350]	valid_0's multi_logloss: 1.41249
# [400]	valid_0's multi_logloss: 1.41142
# [450]	valid_0's multi_logloss: 1.41049
# [500]	valid_0's multi_logloss: 1.40952
# [550]	valid_0's multi_logloss: 1.40897
# [600]	valid_0's multi_logloss: 1.40857
# [650]	valid_0's multi_logloss: 1.40818
# [700]	valid_0's multi_logloss: 1.4077
# [750]	valid_0's multi_logloss: 1.40738
# [800]	valid_0's multi_logloss: 1.40691
# [850]	valid_0's multi_logloss: 1.40665
# [900]	valid_0's multi_logloss: 1.40617
# [950]	valid_0's multi_logloss: 1.40571
# [1000]	valid_0's multi_logloss: 1.40529
# [1050]	valid_0's multi_logloss: 1.40467
# [1100]	valid_0's multi_logloss: 1.40428
# [1150]	valid_0's multi_logloss: 1.40388
# [1200]	valid_0's multi_logloss: 1.40341
# [1250]	valid_0's multi_logloss: 1.40316
# [1300]	valid_0's multi_logloss: 1.40298
# [1350]	valid_0's multi_logloss: 1.40268
# [1400]	valid_0's multi_logloss: 1.40235
# [1450]	valid_0's multi_logloss: 1.40229
# [1500]	valid_0's multi_logloss: 1.40202
# [1550]	valid_0's multi_logloss: 1.40187
# [1600]	valid_0's multi_logloss: 1.40169
# [1650]	valid_0's multi_logloss: 1.40149
# [1700]	valid_0's multi_logloss: 1.4012
# [1750]	valid_0's multi_logloss: 1.40092
# [1800]	valid_0's multi_logloss: 1.40066
# [1850]	valid_0's multi_logloss: 1.40049
# [1900]	valid_0's multi_logloss: 1.40036
# [1950]	valid_0's multi_logloss: 1.40028
# [2000]	valid_0's multi_logloss: 1.40018
# [2050]	valid_0's multi_logloss: 1.39998
# [2100]	valid_0's multi_logloss: 1.39976
# [2150]	valid_0's multi_logloss: 1.39974
# [2200]	valid_0's multi_logloss: 1.39956
# Early stopping, best iteration is:
# [2180]	valid_0's multi_logloss: 1.39945
# fit fold=5 16.885[s]
# Fold 4 Macro-F1: 0.2182
# FINISHED | Whole Macro-F1: 0.2418

# %%
def visualize_importance(models, feat_train_df):
    """lightGBM の model 配列の feature importance を plot する
    CVごとのブレを boxen plot として表現します.

    args:
        models:
            List of lightGBM models
        feat_train_df:
            学習時に使った DataFrame
    """
    feature_importance_df = pd.DataFrame()
    for i, model in enumerate(models):
        _df = pd.DataFrame()
        _df['feature_importance'] = model.feature_importances_
        _df['column'] = feat_train_df.columns
        _df['fold'] = i + 1
        feature_importance_df = pd.concat([feature_importance_df, _df], axis=0, ignore_index=True)

    order = feature_importance_df.groupby('column')\
        .sum()[['feature_importance']]\
        .sort_values('feature_importance', ascending=False).index[:50]

    fig, ax = plt.subplots(figsize=(max(6, len(order) * .4), 7))
    sns.boxenplot(data=feature_importance_df, x='column', y='feature_importance', order=order, ax=ax, palette='viridis')
    ax.tick_params(axis='x', rotation=90)
    ax.grid()
    fig.tight_layout()
    return fig, ax

# %%
fig, ax = visualize_importance(models, train_x)

# %%
pred_lgb = np.array([model.predict(test_x.values) for model in models])

# %%
from scipy.stats import mode
pred_lgbs = mode(pred_lgb)[0][0]

# %%
submit_df = pd.DataFrame({'y': pred_lgbs})
submit_df.index.name = 'id'
submit_df.to_csv(emp+'submission.csv')
