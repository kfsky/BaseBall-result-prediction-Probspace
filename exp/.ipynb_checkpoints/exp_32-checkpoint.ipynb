# %%
emp = "exp_31_"

# %%
import numpy as np 
import pandas as pd 
import re
import typing as tp

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import string
import lightgbm as lgb
import xgboost as xgb
from tqdm import tqdm

import os
from glob import glob

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics

from collections import Counter
pd.set_option('display.max_columns', 100)
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']


import category_encoders as ce
from sklearn.model_selection import KFold, StratifiedKFold

from xfeat import (SelectCategorical, LabelEncoder, Pipeline, ConcatCombination, SelectNumerical, 
                   ArithmeticCombinations, TargetEncoder, aggregation, GBDTFeatureSelector, GBDTFeatureExplorer)

import warnings

# %%
train_df = pd.read_csv("../train_data.csv")
test_df = pd.read_csv("../test_data.csv")
game_df = pd.read_csv("../game_info.csv")
game_df = game_df.drop('Unnamed: 0',axis=1)

# bool型が面倒なので、先に変換する
bool_list = ["b1", "b2", "b3"]
for i in bool_list:
    train_df[i] = train_df[i]*1
    test_df[i] = test_df[i]*1

# baselineとして、train_dfにしかないデータは削除する。
# 実験のどこかで追加できるように前処理をかける
_train_df = train_df.copy()
drop_list = [
    "pitchType", "speed", "ballPositionLabel", "ballX",
    "ballY", "dir", "dist", "battingType", "isOuts"
]
train_df = train_df.drop(drop_list, axis=1)

# %%
from contextlib import contextmanager
from time import time

@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)

# %%
# 前処理前の準備として実施する
train_df["counts"] = train_df[['S', 'B']].apply(lambda x: '{}-{}'.format(x[0], x[1]),axis=1)
test_df["counts"] = test_df[['S', 'B']].apply(lambda x: '{}-{}'.format(x[0], x[1]),axis=1)

# exp4との差
train_df["total_counts"] = train_df[['S', 'B', 'O']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]),axis=1)
test_df["total_counts"] = test_df[['S', 'B', 'O']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]),axis=1)

# exp5との差
train_df["runner_status"] = train_df[['b1', 'b2', 'b3']].apply(lambda x:'{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
test_df["runner_status"] = test_df[['b1', 'b2', 'b3']].apply(lambda x:'{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

# %%
# baseBlock 

class BaseBlock(object):
    def fit(self, input_df, y=None):
        return self.transform(input_df)
    
    def transform(self, input_df):
        raise NotImplementedError()
        
# CountEncoding
class CountEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        self.encoder = ce.CountEncoder()
        self.encoder.fit(input_df[self.cols])
        return self.encoder.transform(input_df[self.cols]).add_prefix("CE_")
    
# OneHotEncoding
class OneHotEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        self.encoder = ce.OneHotEncoder(use_cat_names=True)
        self.encoder.fit(input_df[self.cols])
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        return self.encoder.transform(input_df[self.cols]).add_prefix("OHE_")

# OrdinalEncoding
class OrdinalEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        self.encoder = ce.OrdinalEncoder()
        self.encoder.fit(input_df[self.cols])
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        return self.encoder.transform(input_df[self.cols]).add_prefix("OE_")

# %%
# 前処理の追加をする関数
def get_top_bottom(x):
    if '表' in x:
        return 0
    else:
        return 1

def get_inning(input_df):
    output_df = pd.DataFrame()
    
    output_df['top_bottom'] = input_df['inning'].apply(lambda x: get_top_bottom(x))
    output_df['inning_num'] = input_df['inning'].apply(lambda x: re.sub("\\D", "", x))
    
    return output_df

# ピッチャー左対バッター右
def left_vs_right(x, y):
    if x=="L" and y=='R':
        return 1
    else:
        return 0

def right_vs_left(x,y):
    if x=='R' and y=='L':
        return 1
    else:
        return 0

def get_pvsb(input_df):
    output_df = pd.DataFrame()
    output_df['left_right'] = input_df[['pitcherHand', 'batterHand']].apply(lambda x: left_vs_right(x[0], x[1]),axis=1)
    output_df['right_left'] = input_df[['pitcherHand', 'batterHand']].apply(lambda x: right_vs_left(x[0], x[1]),axis=1)
    
    return output_df

def get_agg_inning(input_df):
    cols = "inning"
    
    output_df = pd.DataFrame()
    output_df, agg_cols = aggregation(input_df,
                                     group_key = cols,
                                     group_values = ["totalPitchingCount"],
                                     agg_methods = ["max","median", "mean", "std", "var"]
                                     )
    
    return output_df[agg_cols]


def get_agg_runner_status(input_df):
    cols = "runner_status"
    
    output_df = pd.DataFrame()
    output_df, agg_cols = aggregation(input_df,
                                     group_key=cols,
                                     group_values=["totalPitchingCount"],
                                     agg_methods = ["max", "median", "mean", "std", "var"]
                                     )
    
    return output_df[agg_cols]


def full_count_search(x,y):
    if x==3 and y==2:
        return 1
    else:
        return 0


def get_full_count(input_df):
    output_df = pd.DataFrame()
    
    output_df["full_count"] = input_df[["B", "S"]].apply(lambda x: full_count_search(x[0], x[1]), axis=1)
    
    return output_df

# 対戦カードの情報を追加する
def get_match(input_df):
    _input_df = pd.merge(input_df, game_df, on="gameID", how="left")
    _input_df["match"] = _input_df["topTeam"] + "vs" + _input_df["bottomTeam"]
    
    cols = [
        "match"
    ]
    
    encoder = CountEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df.astype(str))
    
    return output_df

# セ・パの情報を入れる（追加で日本シリーズかどうかも判定）
def search_central_league(x, y):
    central_team = ['巨人', 'DeNA','ヤクルト', '広島', '中日', '阪神']
    if x in central_team and y in central_team:
        return 1
    else:
        return 0
    
#n日本シリーズのデータがtestにしかないから、意味ない？
def search_japan_series(x, y):
    card_team = ['ソフトバンク', '巨人']
    if x in card_team and y in card_team:
        return 1
    elif y in card_team and x in card_team:
        return 1
    else:
        return 0
    
# 判定結果を特徴量に
def get_league(input_df):
    _input_df = pd.merge(input_df, game_df, on="gameID", how="left")
    output_df = pd.DataFrame()
    
    output_df["league"] = _input_df[["topTeam", "bottomTeam"]].apply(lambda x: search_central_league(x[0], x[1]), axis=1)
    #output_df["japan_series"] = _input_df[["topTeam", "bottomTeam"]].apply(lambda x: search_japan_series(x[0], x[1]), axis=1)
    
    return output_df

# その回何人目のバッターなのかのフラグ
def get_count_batter(input_df):
    output_df = pd.DataFrame()
    
    output_df["count_batter"] = input_df["O"]+input_df["b1"]+input_df["b2"]+input_df["b3"]+1
    
    return output_df

# ホームラン数が多い人に対してのフラグを実装（OHEなくしたから効果あるか）
def search_HR_batter(x):
    HR_list = ['岡本 和真','レアード','山川 穂高','中田 翔','鈴木 誠也','浅村 栄斗']
    
    if x in HR_list:
        return 1
    else:
        return 0
    
def get_HR_batter(input_df):
    output_df = pd.DataFrame()
    output_df["HR_batters_flag"] = input_df.batter.apply(lambda x: search_HR_batter(x))
    
    return output_df

# ホームラン数に関するフラグが少し効果あったので、投手（奪三振でも実施）
def search_KK_pitcher(x):
    KK_list =['ムーア', '森下 暢仁', '柳 裕也', '杉浦 稔大', '弓削 隼人', '山本 由伸', '戸郷 翔征', 'アルバース',
       '有原 航平', 'モイネロ', '石橋 良太', '高橋 光成', '種市 篤暉', 'ギャレット', '則本 昂大', '菅野 智之',
       '梅津 晃大', '今永 昇太', 'ジャクソン', '中村 稔弥']
    
    if x in KK_list:
        return 1
    else:
        return 0
    
def get_KK_pitcher(input_df):
    output_df = pd.DataFrame()
    output_df["KK_pitcher_flag"] = input_df.pitcher.apply(lambda x: search_KK_pitcher(x))
    
    return output_df

# average_hitter(効果なし)
def search_average_hitter(x):
    avg_hitter_list = ['宮崎 敏郎', '岡本 和真', '荻野 貴司', '高橋 周平', '鈴木 大地', 'ロメロ', '佐野 恵太', '京田 陽太',
       '浅村 栄斗']
    
    if x in avg_hitter_list:
        return 1
    else:
        return 0
    
def get_average_hitter(input_df):
    output_df = pd.DataFrame()
    output_df["average_hitter_flag"] = input_df.pitcher.apply(lambda x: search_average_hitter(x))
    
    return output_df

# ピッチャーとバッターに球団情報を与える
def b_p_detail(input_df):
    _input_df = pd.merge(input_df, game_df, on='gameID', how='left')
    
    _input_df.loc[_input_df['inning'].str.contains("表"), "batter_detail"] = _input_df["batter"] + '_' + _input_df["topTeam"]
    _input_df.loc[_input_df['inning'].str.contains("裏"), "batter_detail"] = _input_df["batter"] + '_' + _input_df["bottomTeam"]
    _input_df.loc[_input_df['inning'].str.contains("表"), "pitcher_detail"] = _input_df["pitcher"] + '_' + _input_df["bottomTeam"]
    _input_df.loc[_input_df['inning'].str.contains("裏"), "pitcher_detail"] = _input_df["pitcher"] + '_' + _input_df["topTeam"]
    
    cols = [
        "batter_detail",
        "pitcher_detail"
    ]
    
    encoder = CountEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df.astype(str))
    
    return output_df

def ballPositionLabel_ratio(input_df):
    # 球種ごとにpivottableを作成して、正規化
    _df = _train_df.pivot_table(values="id",index='pitcher',columns='ballPositionLabel',aggfunc='count').fillna(0).apply(lambda x: x/x.sum(), axis=1)
    
    output_df = pd.merge(input_df, _df, on="pitcher", how="left")
    
    agg_cols = ['内角低め', '外角高め', '内角中心', '外角中心', '真ん中低め', 'ど真ん中', '外角低め', '真ん中高め',
       '内角高め', '低め', '高め', '中心']
    
    return output_df[agg_cols]

# %%
# encoding系の処理を行う関数
def get_ce_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
        'pitcher',
        'pitcherHand',
        'batter',
        'batterHand',
        'inning',
        'counts',
        'total_counts',
        'runner_status'
    ]
    
    encoder = CountEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df.astype(str))
    return output_df

def get_oe_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
        #'pitcher',
        'pitcherHand',
        #'batter',
        'batterHand',
        'inning',
        'counts',
        'total_counts',
        'runner_status'
    ]
    encoder = OrdinalEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df)
    return output_df

def get_ohe_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
       #'pitcher',
        'pitcherHand',
        #'batter',
        'batterHand',
        'inning',
        'counts',
        'total_counts',
        'runner_status'
    ]
    encoder = OneHotEncodingBlock(cols=cols)
    output_df = encoder.fit(_input_df)
    return output_df


# numeric_feature
def create_numeric_feature(input_df):
    use_columns = [
        'totalPitchingCount',
        'B', 'S', 'O','b1', 'b2', 'b3',
    ]

    return input_df[use_columns].copy()

# %%
# 前処理関数を順々に処理していく関数
def to_features(train, test):
    input_df = pd.concat([train, test]).reset_index(drop=True)

    processes = [
        get_oe_features,
        get_ce_features,
        get_ohe_features,
        create_numeric_feature,
        get_inning,
        get_pvsb,
        get_agg_inning,
        get_agg_runner_status,
        get_full_count,
        get_match,
        get_league,
        get_count_batter,
        get_HR_batter,
        get_KK_pitcher,
        ballPositionLabel_ratio
    ]

    output_df = pd.DataFrame()
    for func in tqdm(processes):
        _df = func(input_df)
        assert len(_df) == len(input_df), func.__name__
        output_df = pd.concat([output_df, _df], axis=1)

    train_x = output_df.iloc[:len(train)] 
    test_x = output_df.iloc[len(train):].reset_index(drop=True)
    return train_x, test_x

# %%
target_data = "y" 

train_x, test_x = to_features(train_df, test_df)
train_ys_for_split = train_df[target_data]
train_ys = train_df[target_data].values
# Out:
#  13%|█▎        | 2/15 [00:00<00:02,  4.55it/s]/home/kengo-fujii/anaconda3/envs/py36/lib/python3.6/site-packages/category_encoders/utils.py:21: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# 100%|██████████| 15/15 [00:03<00:00,  4.87it/s]

# %%
def fit_lgbm(X, y, cv, params: dict=None, verbose: int=50):
    """lightGBM を CrossValidation の枠組みで学習を行なう function"""
    metric_func = f1_score

    # パラメータがないときは、空の dict で置き換える
    if params is None:
        params = {}

    models = []
    # training data の target と同じだけのゼロ配列を用意
    # float にしないと悲しい事件が起こるのでそこだけ注意
    oof_pred = np.zeros_like(y, dtype=np.float)

    for i, (idx_train, idx_valid) in enumerate(cv): 
        # この部分が交差検証のところです。データセットを cv instance によって分割します
        # training data を trian/valid に分割
        x_train, y_train = X[idx_train], y[idx_train]
        x_valid, y_valid = X[idx_valid], y[idx_valid]

        clf = lgb.LGBMClassifier(**params)

        with timer(prefix='fit fold={} '.format(i + 1)):
            clf.fit(x_train, y_train, 
                    eval_set=[(x_valid, y_valid)],  
                    early_stopping_rounds=verbose,
                    verbose=verbose)

        pred_i = clf.predict(x_valid)

        oof_pred[idx_valid] = pred_i
        models.append(clf)

        print(f'Fold {i} Macro-F1: {metric_func(y_valid, pred_i, average="macro") :.4f}')

    score = metric_func(y, oof_pred, average="macro") 
    print('FINISHED | Whole Macro-F1: {:.4f}'.format(score))
    return oof_pred, models

# %%
lgm_params = {  
    "n_estimators": 20000,
    "objective": 'multiclass',
    "num_class":8,
    "learning_rate": 0.01,
    "num_leaves": 36,
    "random_state": 71,
    "n_jobs": -1,
    "importance_type": "gain",
    'colsample_bytree': .5,
    "reg_lambda": 5,
    "max_depth":7,
    }

fold = StratifiedKFold(n_splits=11, shuffle=True, random_state=71)
cv = list(fold.split(train_x, train_ys)) # もともとが generator なため明示的に list に変換する

# %%
oof, models = fit_lgbm(train_x.values, train_ys, cv, params=lgm_params)
# Out:
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.45853
# [100]	valid_0's multi_logloss: 1.43878
# [150]	valid_0's multi_logloss: 1.42786
# [200]	valid_0's multi_logloss: 1.42122
# [250]	valid_0's multi_logloss: 1.41742
# [300]	valid_0's multi_logloss: 1.41401
# [350]	valid_0's multi_logloss: 1.41142
# [400]	valid_0's multi_logloss: 1.40926
# [450]	valid_0's multi_logloss: 1.40662
# [500]	valid_0's multi_logloss: 1.40478
# [550]	valid_0's multi_logloss: 1.40297
# [600]	valid_0's multi_logloss: 1.40108
# [650]	valid_0's multi_logloss: 1.39974
# [700]	valid_0's multi_logloss: 1.39847
# [750]	valid_0's multi_logloss: 1.3976
# [800]	valid_0's multi_logloss: 1.39672
# [850]	valid_0's multi_logloss: 1.39529
# [900]	valid_0's multi_logloss: 1.394
# [950]	valid_0's multi_logloss: 1.39326
# [1000]	valid_0's multi_logloss: 1.39238
# [1050]	valid_0's multi_logloss: 1.39158
# [1100]	valid_0's multi_logloss: 1.39021
# [1150]	valid_0's multi_logloss: 1.38896
# [1200]	valid_0's multi_logloss: 1.38803
# [1250]	valid_0's multi_logloss: 1.38711
# [1300]	valid_0's multi_logloss: 1.3862
# [1350]	valid_0's multi_logloss: 1.38506
# [1400]	valid_0's multi_logloss: 1.38422
# [1450]	valid_0's multi_logloss: 1.38341
# [1500]	valid_0's multi_logloss: 1.38267
# [1550]	valid_0's multi_logloss: 1.38168
# [1600]	valid_0's multi_logloss: 1.38049
# [1650]	valid_0's multi_logloss: 1.37962
# [1700]	valid_0's multi_logloss: 1.37883
# [1750]	valid_0's multi_logloss: 1.37784
# [1800]	valid_0's multi_logloss: 1.37742
# [1850]	valid_0's multi_logloss: 1.37709
# [1900]	valid_0's multi_logloss: 1.37664
# [1950]	valid_0's multi_logloss: 1.3762
# [2000]	valid_0's multi_logloss: 1.37553
# [2050]	valid_0's multi_logloss: 1.37493
# [2100]	valid_0's multi_logloss: 1.37407
# [2150]	valid_0's multi_logloss: 1.37365
# [2200]	valid_0's multi_logloss: 1.37342
# [2250]	valid_0's multi_logloss: 1.37323
# [2300]	valid_0's multi_logloss: 1.37285
# [2350]	valid_0's multi_logloss: 1.37209
# [2400]	valid_0's multi_logloss: 1.37139
# [2450]	valid_0's multi_logloss: 1.37092
# [2500]	valid_0's multi_logloss: 1.37045
# [2550]	valid_0's multi_logloss: 1.37016
# [2600]	valid_0's multi_logloss: 1.37015
# [2650]	valid_0's multi_logloss: 1.37
# Early stopping, best iteration is:
# [2638]	valid_0's multi_logloss: 1.36993
# fit fold=1 44.596[s]
# Fold 0 Macro-F1: 0.3287
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46085
# [100]	valid_0's multi_logloss: 1.44278
# [150]	valid_0's multi_logloss: 1.43291
# [200]	valid_0's multi_logloss: 1.42695
# [250]	valid_0's multi_logloss: 1.42253
# [300]	valid_0's multi_logloss: 1.41895
# [350]	valid_0's multi_logloss: 1.41658
# [400]	valid_0's multi_logloss: 1.41433
# [450]	valid_0's multi_logloss: 1.41243
# [500]	valid_0's multi_logloss: 1.4109
# [550]	valid_0's multi_logloss: 1.40958
# [600]	valid_0's multi_logloss: 1.40835
# [650]	valid_0's multi_logloss: 1.40748
# [700]	valid_0's multi_logloss: 1.40613
# [750]	valid_0's multi_logloss: 1.40537
# [800]	valid_0's multi_logloss: 1.4045
# [850]	valid_0's multi_logloss: 1.40375
# [900]	valid_0's multi_logloss: 1.40296
# [950]	valid_0's multi_logloss: 1.40254
# [1000]	valid_0's multi_logloss: 1.4017
# [1050]	valid_0's multi_logloss: 1.40111
# [1100]	valid_0's multi_logloss: 1.40014
# [1150]	valid_0's multi_logloss: 1.3992
# [1200]	valid_0's multi_logloss: 1.3984
# [1250]	valid_0's multi_logloss: 1.39745
# [1300]	valid_0's multi_logloss: 1.39636
# [1350]	valid_0's multi_logloss: 1.39561
# [1400]	valid_0's multi_logloss: 1.39494
# [1450]	valid_0's multi_logloss: 1.39407
# [1500]	valid_0's multi_logloss: 1.39313
# [1550]	valid_0's multi_logloss: 1.39238
# [1600]	valid_0's multi_logloss: 1.39175
# [1650]	valid_0's multi_logloss: 1.39113
# [1700]	valid_0's multi_logloss: 1.39046
# [1750]	valid_0's multi_logloss: 1.39034
# Early stopping, best iteration is:
# [1743]	valid_0's multi_logloss: 1.39032
# fit fold=2 34.260[s]
# Fold 1 Macro-F1: 0.2448
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.45959
# [100]	valid_0's multi_logloss: 1.44074
# [150]	valid_0's multi_logloss: 1.43071
# [200]	valid_0's multi_logloss: 1.42448
# [250]	valid_0's multi_logloss: 1.42017
# [300]	valid_0's multi_logloss: 1.41727
# [350]	valid_0's multi_logloss: 1.41444
# [400]	valid_0's multi_logloss: 1.41206
# [450]	valid_0's multi_logloss: 1.40964
# [500]	valid_0's multi_logloss: 1.40707
# [550]	valid_0's multi_logloss: 1.40548
# [600]	valid_0's multi_logloss: 1.40325
# [650]	valid_0's multi_logloss: 1.40125
# [700]	valid_0's multi_logloss: 1.39985
# [750]	valid_0's multi_logloss: 1.39855
# [800]	valid_0's multi_logloss: 1.39716
# [850]	valid_0's multi_logloss: 1.396
# [900]	valid_0's multi_logloss: 1.39482
# [950]	valid_0's multi_logloss: 1.394
# [1000]	valid_0's multi_logloss: 1.39269
# [1050]	valid_0's multi_logloss: 1.39147
# [1100]	valid_0's multi_logloss: 1.39056
# [1150]	valid_0's multi_logloss: 1.3897
# [1200]	valid_0's multi_logloss: 1.38896
# [1250]	valid_0's multi_logloss: 1.38828
# [1300]	valid_0's multi_logloss: 1.3875
# [1350]	valid_0's multi_logloss: 1.38659
# [1400]	valid_0's multi_logloss: 1.38582
# [1450]	valid_0's multi_logloss: 1.38533
# [1500]	valid_0's multi_logloss: 1.38499
# [1550]	valid_0's multi_logloss: 1.38411
# [1600]	valid_0's multi_logloss: 1.38314
# [1650]	valid_0's multi_logloss: 1.38251
# [1700]	valid_0's multi_logloss: 1.38217
# [1750]	valid_0's multi_logloss: 1.38147
# [1800]	valid_0's multi_logloss: 1.38127
# [1850]	valid_0's multi_logloss: 1.3804
# [1900]	valid_0's multi_logloss: 1.37996
# [1950]	valid_0's multi_logloss: 1.37955
# [2000]	valid_0's multi_logloss: 1.37928
# [2050]	valid_0's multi_logloss: 1.37859
# [2100]	valid_0's multi_logloss: 1.37841
# [2150]	valid_0's multi_logloss: 1.37807
# [2200]	valid_0's multi_logloss: 1.3778
# [2250]	valid_0's multi_logloss: 1.37757
# [2300]	valid_0's multi_logloss: 1.37714
# [2350]	valid_0's multi_logloss: 1.37686
# [2400]	valid_0's multi_logloss: 1.37643
# [2450]	valid_0's multi_logloss: 1.37639
# [2500]	valid_0's multi_logloss: 1.37605
# [2550]	valid_0's multi_logloss: 1.37543
# [2600]	valid_0's multi_logloss: 1.37499
# [2650]	valid_0's multi_logloss: 1.37482
# [2700]	valid_0's multi_logloss: 1.37448
# [2750]	valid_0's multi_logloss: 1.37449
# Early stopping, best iteration is:
# [2719]	valid_0's multi_logloss: 1.37439
# fit fold=3 51.805[s]
# Fold 2 Macro-F1: 0.3230
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46051
# [100]	valid_0's multi_logloss: 1.44289
# [150]	valid_0's multi_logloss: 1.4331
# [200]	valid_0's multi_logloss: 1.4269
# [250]	valid_0's multi_logloss: 1.42275
# [300]	valid_0's multi_logloss: 1.41939
# [350]	valid_0's multi_logloss: 1.41662
# [400]	valid_0's multi_logloss: 1.41425
# [450]	valid_0's multi_logloss: 1.41171
# [500]	valid_0's multi_logloss: 1.40988
# [550]	valid_0's multi_logloss: 1.40789
# [600]	valid_0's multi_logloss: 1.40636
# [650]	valid_0's multi_logloss: 1.40489
# [700]	valid_0's multi_logloss: 1.40349
# [750]	valid_0's multi_logloss: 1.40199
# [800]	valid_0's multi_logloss: 1.40095
# [850]	valid_0's multi_logloss: 1.40004
# [900]	valid_0's multi_logloss: 1.39919
# [950]	valid_0's multi_logloss: 1.39843
# [1000]	valid_0's multi_logloss: 1.39756
# [1050]	valid_0's multi_logloss: 1.39681
# [1100]	valid_0's multi_logloss: 1.39583
# [1150]	valid_0's multi_logloss: 1.39497
# [1200]	valid_0's multi_logloss: 1.3942
# [1250]	valid_0's multi_logloss: 1.39345
# [1300]	valid_0's multi_logloss: 1.39238
# [1350]	valid_0's multi_logloss: 1.39171
# [1400]	valid_0's multi_logloss: 1.39121
# [1450]	valid_0's multi_logloss: 1.39067
# [1500]	valid_0's multi_logloss: 1.39003
# [1550]	valid_0's multi_logloss: 1.38947
# [1600]	valid_0's multi_logloss: 1.38889
# [1650]	valid_0's multi_logloss: 1.38829
# [1700]	valid_0's multi_logloss: 1.38749
# [1750]	valid_0's multi_logloss: 1.38679
# [1800]	valid_0's multi_logloss: 1.38613
# [1850]	valid_0's multi_logloss: 1.38539
# [1900]	valid_0's multi_logloss: 1.38463
# [1950]	valid_0's multi_logloss: 1.38413
# [2000]	valid_0's multi_logloss: 1.3833
# [2050]	valid_0's multi_logloss: 1.38258
# [2100]	valid_0's multi_logloss: 1.38179
# [2150]	valid_0's multi_logloss: 1.38107
# [2200]	valid_0's multi_logloss: 1.38029
# [2250]	valid_0's multi_logloss: 1.37958
# [2300]	valid_0's multi_logloss: 1.37856
# [2350]	valid_0's multi_logloss: 1.37798
# [2400]	valid_0's multi_logloss: 1.37722
# [2450]	valid_0's multi_logloss: 1.37694
# [2500]	valid_0's multi_logloss: 1.37664
# [2550]	valid_0's multi_logloss: 1.37588
# [2600]	valid_0's multi_logloss: 1.37544
# [2650]	valid_0's multi_logloss: 1.37522
# [2700]	valid_0's multi_logloss: 1.37492
# [2750]	valid_0's multi_logloss: 1.37475
# [2800]	valid_0's multi_logloss: 1.37412
# [2850]	valid_0's multi_logloss: 1.37379
# [2900]	valid_0's multi_logloss: 1.37335
# [2950]	valid_0's multi_logloss: 1.3732
# [3000]	valid_0's multi_logloss: 1.37296
# [3050]	valid_0's multi_logloss: 1.37265
# [3100]	valid_0's multi_logloss: 1.37209
# [3150]	valid_0's multi_logloss: 1.37156
# [3200]	valid_0's multi_logloss: 1.37089
# [3250]	valid_0's multi_logloss: 1.37079
# [3300]	valid_0's multi_logloss: 1.37061
# [3350]	valid_0's multi_logloss: 1.37022
# [3400]	valid_0's multi_logloss: 1.36992
# [3450]	valid_0's multi_logloss: 1.36977
# [3500]	valid_0's multi_logloss: 1.36962
# [3550]	valid_0's multi_logloss: 1.3692
# [3600]	valid_0's multi_logloss: 1.36894
# [3650]	valid_0's multi_logloss: 1.36883
# [3700]	valid_0's multi_logloss: 1.36856
# [3750]	valid_0's multi_logloss: 1.36848
# [3800]	valid_0's multi_logloss: 1.36807
# [3850]	valid_0's multi_logloss: 1.36792
# [3900]	valid_0's multi_logloss: 1.36771
# [3950]	valid_0's multi_logloss: 1.36743
# [4000]	valid_0's multi_logloss: 1.36708
# [4050]	valid_0's multi_logloss: 1.36707
# Early stopping, best iteration is:
# [4016]	valid_0's multi_logloss: 1.36694
# fit fold=4 84.110[s]
# Fold 3 Macro-F1: 0.3256
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.4556
# [100]	valid_0's multi_logloss: 1.43447
# [150]	valid_0's multi_logloss: 1.42323
# [200]	valid_0's multi_logloss: 1.41675
# [250]	valid_0's multi_logloss: 1.41229
# [300]	valid_0's multi_logloss: 1.4084
# [350]	valid_0's multi_logloss: 1.40554
# [400]	valid_0's multi_logloss: 1.40333
# [450]	valid_0's multi_logloss: 1.40122
# [500]	valid_0's multi_logloss: 1.3996
# [550]	valid_0's multi_logloss: 1.39798
# [600]	valid_0's multi_logloss: 1.39636
# [650]	valid_0's multi_logloss: 1.3948
# [700]	valid_0's multi_logloss: 1.39337
# [750]	valid_0's multi_logloss: 1.39217
# [800]	valid_0's multi_logloss: 1.39063
# [850]	valid_0's multi_logloss: 1.38919
# [900]	valid_0's multi_logloss: 1.38771
# [950]	valid_0's multi_logloss: 1.38646
# [1000]	valid_0's multi_logloss: 1.38511
# [1050]	valid_0's multi_logloss: 1.38411
# [1100]	valid_0's multi_logloss: 1.38324
# [1150]	valid_0's multi_logloss: 1.38187
# [1200]	valid_0's multi_logloss: 1.38053
# [1250]	valid_0's multi_logloss: 1.3796
# [1300]	valid_0's multi_logloss: 1.3788
# [1350]	valid_0's multi_logloss: 1.378
# [1400]	valid_0's multi_logloss: 1.37737
# [1450]	valid_0's multi_logloss: 1.3766
# [1500]	valid_0's multi_logloss: 1.37596
# [1550]	valid_0's multi_logloss: 1.37521
# [1600]	valid_0's multi_logloss: 1.37431
# [1650]	valid_0's multi_logloss: 1.37361
# [1700]	valid_0's multi_logloss: 1.37316
# [1750]	valid_0's multi_logloss: 1.37288
# [1800]	valid_0's multi_logloss: 1.37225
# [1850]	valid_0's multi_logloss: 1.37166
# [1900]	valid_0's multi_logloss: 1.37067
# [1950]	valid_0's multi_logloss: 1.37002
# [2000]	valid_0's multi_logloss: 1.36952
# [2050]	valid_0's multi_logloss: 1.36869
# [2100]	valid_0's multi_logloss: 1.36837
# [2150]	valid_0's multi_logloss: 1.36797
# [2200]	valid_0's multi_logloss: 1.36759
# [2250]	valid_0's multi_logloss: 1.3669
# [2300]	valid_0's multi_logloss: 1.36622
# [2350]	valid_0's multi_logloss: 1.36579
# [2400]	valid_0's multi_logloss: 1.36538
# [2450]	valid_0's multi_logloss: 1.36538
# [2500]	valid_0's multi_logloss: 1.36499
# [2550]	valid_0's multi_logloss: 1.36447
# [2600]	valid_0's multi_logloss: 1.36407
# [2650]	valid_0's multi_logloss: 1.36344
# [2700]	valid_0's multi_logloss: 1.36283
# [2750]	valid_0's multi_logloss: 1.36263
# [2800]	valid_0's multi_logloss: 1.36207
# [2850]	valid_0's multi_logloss: 1.3617
# [2900]	valid_0's multi_logloss: 1.36153
# [2950]	valid_0's multi_logloss: 1.3612
# [3000]	valid_0's multi_logloss: 1.36089
# [3050]	valid_0's multi_logloss: 1.36063
# [3100]	valid_0's multi_logloss: 1.36024
# [3150]	valid_0's multi_logloss: 1.36022
# [3200]	valid_0's multi_logloss: 1.35985
# [3250]	valid_0's multi_logloss: 1.35977
# [3300]	valid_0's multi_logloss: 1.35973
# Early stopping, best iteration is:
# [3268]	valid_0's multi_logloss: 1.35967
# fit fold=5 81.812[s]
# Fold 4 Macro-F1: 0.3490
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46099
# [100]	valid_0's multi_logloss: 1.44255
# [150]	valid_0's multi_logloss: 1.43117
# [200]	valid_0's multi_logloss: 1.4231
# [250]	valid_0's multi_logloss: 1.41709
# [300]	valid_0's multi_logloss: 1.41249
# [350]	valid_0's multi_logloss: 1.40886
# [400]	valid_0's multi_logloss: 1.40527
# [450]	valid_0's multi_logloss: 1.40253
# [500]	valid_0's multi_logloss: 1.40049
# [550]	valid_0's multi_logloss: 1.3985
# [600]	valid_0's multi_logloss: 1.39622
# [650]	valid_0's multi_logloss: 1.39423
# [700]	valid_0's multi_logloss: 1.39214
# [750]	valid_0's multi_logloss: 1.39014
# [800]	valid_0's multi_logloss: 1.38839
# [850]	valid_0's multi_logloss: 1.38642
# [900]	valid_0's multi_logloss: 1.38456
# [950]	valid_0's multi_logloss: 1.38289
# [1000]	valid_0's multi_logloss: 1.38131
# [1050]	valid_0's multi_logloss: 1.37978
# [1100]	valid_0's multi_logloss: 1.37824
# [1150]	valid_0's multi_logloss: 1.37686
# [1200]	valid_0's multi_logloss: 1.37557
# [1250]	valid_0's multi_logloss: 1.37415
# [1300]	valid_0's multi_logloss: 1.37315
# [1350]	valid_0's multi_logloss: 1.3717
# [1400]	valid_0's multi_logloss: 1.37063
# [1450]	valid_0's multi_logloss: 1.36982
# [1500]	valid_0's multi_logloss: 1.36877
# [1550]	valid_0's multi_logloss: 1.36783
# [1600]	valid_0's multi_logloss: 1.36677
# [1650]	valid_0's multi_logloss: 1.36562
# [1700]	valid_0's multi_logloss: 1.36414
# [1750]	valid_0's multi_logloss: 1.36283
# [1800]	valid_0's multi_logloss: 1.36175
# [1850]	valid_0's multi_logloss: 1.36049
# [1900]	valid_0's multi_logloss: 1.3594
# [1950]	valid_0's multi_logloss: 1.35843
# [2000]	valid_0's multi_logloss: 1.35734
# [2050]	valid_0's multi_logloss: 1.35661
# [2100]	valid_0's multi_logloss: 1.35564
# [2150]	valid_0's multi_logloss: 1.35488
# [2200]	valid_0's multi_logloss: 1.35401
# [2250]	valid_0's multi_logloss: 1.35317
# [2300]	valid_0's multi_logloss: 1.35242
# [2350]	valid_0's multi_logloss: 1.35179
# [2400]	valid_0's multi_logloss: 1.35097
# [2450]	valid_0's multi_logloss: 1.35054
# [2500]	valid_0's multi_logloss: 1.34985
# [2550]	valid_0's multi_logloss: 1.34898
# [2600]	valid_0's multi_logloss: 1.34825
# [2650]	valid_0's multi_logloss: 1.34748
# [2700]	valid_0's multi_logloss: 1.34694
# [2750]	valid_0's multi_logloss: 1.34674
# [2800]	valid_0's multi_logloss: 1.34666
# [2850]	valid_0's multi_logloss: 1.34659
# [2900]	valid_0's multi_logloss: 1.34615
# [2950]	valid_0's multi_logloss: 1.3454
# [3000]	valid_0's multi_logloss: 1.34478
# [3050]	valid_0's multi_logloss: 1.3443
# [3100]	valid_0's multi_logloss: 1.34375
# [3150]	valid_0's multi_logloss: 1.34348
# [3200]	valid_0's multi_logloss: 1.3431
# [3250]	valid_0's multi_logloss: 1.34272
# [3300]	valid_0's multi_logloss: 1.3423
# [3350]	valid_0's multi_logloss: 1.34178
# [3400]	valid_0's multi_logloss: 1.34161
# [3450]	valid_0's multi_logloss: 1.34113
# [3500]	valid_0's multi_logloss: 1.34083
# [3550]	valid_0's multi_logloss: 1.34052
# [3600]	valid_0's multi_logloss: 1.34
# [3650]	valid_0's multi_logloss: 1.33975
# [3700]	valid_0's multi_logloss: 1.33968
# [3750]	valid_0's multi_logloss: 1.33944
# [3800]	valid_0's multi_logloss: 1.3393
# [3850]	valid_0's multi_logloss: 1.33903
# [3900]	valid_0's multi_logloss: 1.3389
# [3950]	valid_0's multi_logloss: 1.33865
# [4000]	valid_0's multi_logloss: 1.33844
# [4050]	valid_0's multi_logloss: 1.3381
# [4100]	valid_0's multi_logloss: 1.3379
# [4150]	valid_0's multi_logloss: 1.33774
# [4200]	valid_0's multi_logloss: 1.33761
# [4250]	valid_0's multi_logloss: 1.33733
# [4300]	valid_0's multi_logloss: 1.33727
# [4350]	valid_0's multi_logloss: 1.33709
# Early stopping, best iteration is:
# [4337]	valid_0's multi_logloss: 1.33703
# fit fold=6 76.692[s]
# Fold 5 Macro-F1: 0.5073
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46047
# [100]	valid_0's multi_logloss: 1.44475
# [150]	valid_0's multi_logloss: 1.43742
# [200]	valid_0's multi_logloss: 1.43191
# [250]	valid_0's multi_logloss: 1.42833
# [300]	valid_0's multi_logloss: 1.42525
# [350]	valid_0's multi_logloss: 1.4228
# [400]	valid_0's multi_logloss: 1.42014
# [450]	valid_0's multi_logloss: 1.41813
# [500]	valid_0's multi_logloss: 1.41635
# [550]	valid_0's multi_logloss: 1.41514
# [600]	valid_0's multi_logloss: 1.41367
# [650]	valid_0's multi_logloss: 1.41247
# [700]	valid_0's multi_logloss: 1.41135
# [750]	valid_0's multi_logloss: 1.4098
# [800]	valid_0's multi_logloss: 1.40868
# [850]	valid_0's multi_logloss: 1.40779
# [900]	valid_0's multi_logloss: 1.40691
# [950]	valid_0's multi_logloss: 1.40581
# [1000]	valid_0's multi_logloss: 1.40476
# [1050]	valid_0's multi_logloss: 1.4041
# [1100]	valid_0's multi_logloss: 1.4029
# [1150]	valid_0's multi_logloss: 1.40192
# [1200]	valid_0's multi_logloss: 1.40114
# [1250]	valid_0's multi_logloss: 1.40006
# [1300]	valid_0's multi_logloss: 1.39906
# [1350]	valid_0's multi_logloss: 1.39798
# [1400]	valid_0's multi_logloss: 1.39692
# [1450]	valid_0's multi_logloss: 1.39638
# [1500]	valid_0's multi_logloss: 1.39543
# [1550]	valid_0's multi_logloss: 1.3945
# [1600]	valid_0's multi_logloss: 1.39384
# [1650]	valid_0's multi_logloss: 1.39279
# [1700]	valid_0's multi_logloss: 1.39188
# [1750]	valid_0's multi_logloss: 1.39068
# [1800]	valid_0's multi_logloss: 1.3898
# [1850]	valid_0's multi_logloss: 1.38917
# [1900]	valid_0's multi_logloss: 1.38819
# [1950]	valid_0's multi_logloss: 1.38763
# [2000]	valid_0's multi_logloss: 1.38693
# [2050]	valid_0's multi_logloss: 1.38588
# [2100]	valid_0's multi_logloss: 1.3851
# [2150]	valid_0's multi_logloss: 1.38401
# [2200]	valid_0's multi_logloss: 1.38315
# [2250]	valid_0's multi_logloss: 1.38238
# [2300]	valid_0's multi_logloss: 1.38129
# [2350]	valid_0's multi_logloss: 1.38055
# [2400]	valid_0's multi_logloss: 1.37975
# [2450]	valid_0's multi_logloss: 1.37912
# [2500]	valid_0's multi_logloss: 1.37837
# [2550]	valid_0's multi_logloss: 1.37798
# [2600]	valid_0's multi_logloss: 1.37754
# [2650]	valid_0's multi_logloss: 1.37696
# [2700]	valid_0's multi_logloss: 1.37649
# [2750]	valid_0's multi_logloss: 1.37618
# [2800]	valid_0's multi_logloss: 1.37566
# [2850]	valid_0's multi_logloss: 1.37509
# [2900]	valid_0's multi_logloss: 1.37471
# [2950]	valid_0's multi_logloss: 1.37429
# [3000]	valid_0's multi_logloss: 1.37365
# [3050]	valid_0's multi_logloss: 1.37327
# [3100]	valid_0's multi_logloss: 1.37282
# [3150]	valid_0's multi_logloss: 1.37224
# [3200]	valid_0's multi_logloss: 1.37183
# [3250]	valid_0's multi_logloss: 1.37148
# [3300]	valid_0's multi_logloss: 1.37119
# [3350]	valid_0's multi_logloss: 1.37075
# [3400]	valid_0's multi_logloss: 1.37009
# [3450]	valid_0's multi_logloss: 1.36996
# [3500]	valid_0's multi_logloss: 1.36988
# [3550]	valid_0's multi_logloss: 1.36967
# [3600]	valid_0's multi_logloss: 1.36957
# [3650]	valid_0's multi_logloss: 1.36919
# [3700]	valid_0's multi_logloss: 1.36875
# [3750]	valid_0's multi_logloss: 1.36843
# [3800]	valid_0's multi_logloss: 1.36806
# [3850]	valid_0's multi_logloss: 1.36793
# [3900]	valid_0's multi_logloss: 1.36772
# [3950]	valid_0's multi_logloss: 1.36777
# Early stopping, best iteration is:
# [3913]	valid_0's multi_logloss: 1.36764
# fit fold=7 58.821[s]
# Fold 6 Macro-F1: 0.4302
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46456
# [100]	valid_0's multi_logloss: 1.44937
# [150]	valid_0's multi_logloss: 1.44072
# [200]	valid_0's multi_logloss: 1.43543
# [250]	valid_0's multi_logloss: 1.43055
# [300]	valid_0's multi_logloss: 1.42758
# [350]	valid_0's multi_logloss: 1.42544
# [400]	valid_0's multi_logloss: 1.42341
# [450]	valid_0's multi_logloss: 1.42122
# [500]	valid_0's multi_logloss: 1.41928
# [550]	valid_0's multi_logloss: 1.41767
# [600]	valid_0's multi_logloss: 1.41657
# [650]	valid_0's multi_logloss: 1.41556
# [700]	valid_0's multi_logloss: 1.41435
# [750]	valid_0's multi_logloss: 1.41336
# [800]	valid_0's multi_logloss: 1.41218
# [850]	valid_0's multi_logloss: 1.41083
# [900]	valid_0's multi_logloss: 1.40934
# [950]	valid_0's multi_logloss: 1.40843
# [1000]	valid_0's multi_logloss: 1.40722
# [1050]	valid_0's multi_logloss: 1.40604
# [1100]	valid_0's multi_logloss: 1.40457
# [1150]	valid_0's multi_logloss: 1.40373
# [1200]	valid_0's multi_logloss: 1.40249
# [1250]	valid_0's multi_logloss: 1.40108
# [1300]	valid_0's multi_logloss: 1.39984
# [1350]	valid_0's multi_logloss: 1.39881
# [1400]	valid_0's multi_logloss: 1.39794
# [1450]	valid_0's multi_logloss: 1.3973
# [1500]	valid_0's multi_logloss: 1.39633
# [1550]	valid_0's multi_logloss: 1.39536
# [1600]	valid_0's multi_logloss: 1.39433
# [1650]	valid_0's multi_logloss: 1.39331
# [1700]	valid_0's multi_logloss: 1.39239
# [1750]	valid_0's multi_logloss: 1.39158
# [1800]	valid_0's multi_logloss: 1.39093
# [1850]	valid_0's multi_logloss: 1.39012
# [1900]	valid_0's multi_logloss: 1.38937
# [1950]	valid_0's multi_logloss: 1.38885
# [2000]	valid_0's multi_logloss: 1.38828
# [2050]	valid_0's multi_logloss: 1.38754
# [2100]	valid_0's multi_logloss: 1.38672
# [2150]	valid_0's multi_logloss: 1.38648
# [2200]	valid_0's multi_logloss: 1.38584
# [2250]	valid_0's multi_logloss: 1.38539
# [2300]	valid_0's multi_logloss: 1.3847
# [2350]	valid_0's multi_logloss: 1.38427
# [2400]	valid_0's multi_logloss: 1.38369
# [2450]	valid_0's multi_logloss: 1.38323
# [2500]	valid_0's multi_logloss: 1.38276
# [2550]	valid_0's multi_logloss: 1.38242
# [2600]	valid_0's multi_logloss: 1.3821
# [2650]	valid_0's multi_logloss: 1.38152
# [2700]	valid_0's multi_logloss: 1.38146
# [2750]	valid_0's multi_logloss: 1.3812
# [2800]	valid_0's multi_logloss: 1.38115
# [2850]	valid_0's multi_logloss: 1.38097
# [2900]	valid_0's multi_logloss: 1.38066
# [2950]	valid_0's multi_logloss: 1.38035
# [3000]	valid_0's multi_logloss: 1.38043
# Early stopping, best iteration is:
# [2950]	valid_0's multi_logloss: 1.38035
# fit fold=8 48.426[s]
# Fold 7 Macro-F1: 0.2931
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46154
# [100]	valid_0's multi_logloss: 1.44491
# [150]	valid_0's multi_logloss: 1.4351
# [200]	valid_0's multi_logloss: 1.42858
# [250]	valid_0's multi_logloss: 1.42378
# [300]	valid_0's multi_logloss: 1.41954
# [350]	valid_0's multi_logloss: 1.41667
# [400]	valid_0's multi_logloss: 1.41446
# [450]	valid_0's multi_logloss: 1.41223
# [500]	valid_0's multi_logloss: 1.41013
# [550]	valid_0's multi_logloss: 1.40789
# [600]	valid_0's multi_logloss: 1.40646
# [650]	valid_0's multi_logloss: 1.40477
# [700]	valid_0's multi_logloss: 1.40334
# [750]	valid_0's multi_logloss: 1.40175
# [800]	valid_0's multi_logloss: 1.40009
# [850]	valid_0's multi_logloss: 1.39834
# [900]	valid_0's multi_logloss: 1.39711
# [950]	valid_0's multi_logloss: 1.39573
# [1000]	valid_0's multi_logloss: 1.3944
# [1050]	valid_0's multi_logloss: 1.39273
# [1100]	valid_0's multi_logloss: 1.39143
# [1150]	valid_0's multi_logloss: 1.39041
# [1200]	valid_0's multi_logloss: 1.38912
# [1250]	valid_0's multi_logloss: 1.38814
# [1300]	valid_0's multi_logloss: 1.38676
# [1350]	valid_0's multi_logloss: 1.38541
# [1400]	valid_0's multi_logloss: 1.38429
# [1450]	valid_0's multi_logloss: 1.38321
# [1500]	valid_0's multi_logloss: 1.38248
# [1550]	valid_0's multi_logloss: 1.38163
# [1600]	valid_0's multi_logloss: 1.38091
# [1650]	valid_0's multi_logloss: 1.3801
# [1700]	valid_0's multi_logloss: 1.37968
# [1750]	valid_0's multi_logloss: 1.3792
# [1800]	valid_0's multi_logloss: 1.37856
# [1850]	valid_0's multi_logloss: 1.37808
# [1900]	valid_0's multi_logloss: 1.37744
# [1950]	valid_0's multi_logloss: 1.37696
# [2000]	valid_0's multi_logloss: 1.37643
# [2050]	valid_0's multi_logloss: 1.37618
# [2100]	valid_0's multi_logloss: 1.3759
# [2150]	valid_0's multi_logloss: 1.37542
# [2200]	valid_0's multi_logloss: 1.37493
# [2250]	valid_0's multi_logloss: 1.37402
# [2300]	valid_0's multi_logloss: 1.37372
# [2350]	valid_0's multi_logloss: 1.37338
# [2400]	valid_0's multi_logloss: 1.37277
# [2450]	valid_0's multi_logloss: 1.37235
# [2500]	valid_0's multi_logloss: 1.37203
# [2550]	valid_0's multi_logloss: 1.37172
# [2600]	valid_0's multi_logloss: 1.37141
# [2650]	valid_0's multi_logloss: 1.37084
# [2700]	valid_0's multi_logloss: 1.3706
# [2750]	valid_0's multi_logloss: 1.37015
# [2800]	valid_0's multi_logloss: 1.36996
# [2850]	valid_0's multi_logloss: 1.36997
# [2900]	valid_0's multi_logloss: 1.36966
# [2950]	valid_0's multi_logloss: 1.36944
# [3000]	valid_0's multi_logloss: 1.36901
# [3050]	valid_0's multi_logloss: 1.36888
# [3100]	valid_0's multi_logloss: 1.36892
# Early stopping, best iteration is:
# [3094]	valid_0's multi_logloss: 1.36882
# fit fold=9 49.131[s]
# Fold 8 Macro-F1: 0.3436
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46086
# [100]	valid_0's multi_logloss: 1.44341
# [150]	valid_0's multi_logloss: 1.43339
# [200]	valid_0's multi_logloss: 1.42752
# [250]	valid_0's multi_logloss: 1.42341
# [300]	valid_0's multi_logloss: 1.42029
# [350]	valid_0's multi_logloss: 1.41805
# [400]	valid_0's multi_logloss: 1.4162
# [450]	valid_0's multi_logloss: 1.41461
# [500]	valid_0's multi_logloss: 1.41302
# [550]	valid_0's multi_logloss: 1.4111
# [600]	valid_0's multi_logloss: 1.40928
# [650]	valid_0's multi_logloss: 1.4079
# [700]	valid_0's multi_logloss: 1.40676
# [750]	valid_0's multi_logloss: 1.40546
# [800]	valid_0's multi_logloss: 1.40448
# [850]	valid_0's multi_logloss: 1.40363
# [900]	valid_0's multi_logloss: 1.40289
# [950]	valid_0's multi_logloss: 1.402
# [1000]	valid_0's multi_logloss: 1.40133
# [1050]	valid_0's multi_logloss: 1.40054
# [1100]	valid_0's multi_logloss: 1.39948
# [1150]	valid_0's multi_logloss: 1.39889
# [1200]	valid_0's multi_logloss: 1.39834
# [1250]	valid_0's multi_logloss: 1.3979
# [1300]	valid_0's multi_logloss: 1.39753
# [1350]	valid_0's multi_logloss: 1.39703
# [1400]	valid_0's multi_logloss: 1.39612
# [1450]	valid_0's multi_logloss: 1.39546
# [1500]	valid_0's multi_logloss: 1.3947
# [1550]	valid_0's multi_logloss: 1.3941
# [1600]	valid_0's multi_logloss: 1.39349
# [1650]	valid_0's multi_logloss: 1.39265
# [1700]	valid_0's multi_logloss: 1.39167
# [1750]	valid_0's multi_logloss: 1.3913
# [1800]	valid_0's multi_logloss: 1.39048
# [1850]	valid_0's multi_logloss: 1.38989
# [1900]	valid_0's multi_logloss: 1.38959
# [1950]	valid_0's multi_logloss: 1.38892
# [2000]	valid_0's multi_logloss: 1.38859
# [2050]	valid_0's multi_logloss: 1.38774
# [2100]	valid_0's multi_logloss: 1.38746
# [2150]	valid_0's multi_logloss: 1.38733
# [2200]	valid_0's multi_logloss: 1.38736
# Early stopping, best iteration is:
# [2166]	valid_0's multi_logloss: 1.38722
# fit fold=10 36.118[s]
# Fold 9 Macro-F1: 0.2778
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46918
# [100]	valid_0's multi_logloss: 1.45665
# [150]	valid_0's multi_logloss: 1.45046
# [200]	valid_0's multi_logloss: 1.44633
# [250]	valid_0's multi_logloss: 1.4427
# [300]	valid_0's multi_logloss: 1.44033
# [350]	valid_0's multi_logloss: 1.43817
# [400]	valid_0's multi_logloss: 1.43624
# [450]	valid_0's multi_logloss: 1.43463
# [500]	valid_0's multi_logloss: 1.43325
# [550]	valid_0's multi_logloss: 1.43182
# [600]	valid_0's multi_logloss: 1.43065
# [650]	valid_0's multi_logloss: 1.42936
# [700]	valid_0's multi_logloss: 1.42793
# [750]	valid_0's multi_logloss: 1.42648
# [800]	valid_0's multi_logloss: 1.42527
# [850]	valid_0's multi_logloss: 1.42413
# [900]	valid_0's multi_logloss: 1.42265
# [950]	valid_0's multi_logloss: 1.42162
# [1000]	valid_0's multi_logloss: 1.42034
# [1050]	valid_0's multi_logloss: 1.41899
# [1100]	valid_0's multi_logloss: 1.41818
# [1150]	valid_0's multi_logloss: 1.41706
# [1200]	valid_0's multi_logloss: 1.4159
# [1250]	valid_0's multi_logloss: 1.41439
# [1300]	valid_0's multi_logloss: 1.41329
# [1350]	valid_0's multi_logloss: 1.41222
# [1400]	valid_0's multi_logloss: 1.41093
# [1450]	valid_0's multi_logloss: 1.40991
# [1500]	valid_0's multi_logloss: 1.40893
# [1550]	valid_0's multi_logloss: 1.40785
# [1600]	valid_0's multi_logloss: 1.40696
# [1650]	valid_0's multi_logloss: 1.40586
# [1700]	valid_0's multi_logloss: 1.40515
# [1750]	valid_0's multi_logloss: 1.40395
# [1800]	valid_0's multi_logloss: 1.40304
# [1850]	valid_0's multi_logloss: 1.40214
# [1900]	valid_0's multi_logloss: 1.40139
# [1950]	valid_0's multi_logloss: 1.40083
# [2000]	valid_0's multi_logloss: 1.39987
# [2050]	valid_0's multi_logloss: 1.39893
# [2100]	valid_0's multi_logloss: 1.39827
# [2150]	valid_0's multi_logloss: 1.39785
# [2200]	valid_0's multi_logloss: 1.39743
# [2250]	valid_0's multi_logloss: 1.39701
# [2300]	valid_0's multi_logloss: 1.39671
# [2350]	valid_0's multi_logloss: 1.3961
# [2400]	valid_0's multi_logloss: 1.39575
# [2450]	valid_0's multi_logloss: 1.39547
# [2500]	valid_0's multi_logloss: 1.39485
# [2550]	valid_0's multi_logloss: 1.39445
# [2600]	valid_0's multi_logloss: 1.39409
# [2650]	valid_0's multi_logloss: 1.39397
# [2700]	valid_0's multi_logloss: 1.39357
# [2750]	valid_0's multi_logloss: 1.39345
# [2800]	valid_0's multi_logloss: 1.39321
# [2850]	valid_0's multi_logloss: 1.39338
# Early stopping, best iteration is:
# [2813]	valid_0's multi_logloss: 1.39316
# fit fold=11 54.190[s]
# Fold 10 Macro-F1: 0.3295
# FINISHED | Whole Macro-F1: 0.3535

# %%
def visualize_importance(models, feat_train_df):
    """lightGBM の model 配列の feature importance を plot する
    CVごとのブレを boxen plot として表現します.

    args:
        models:
            List of lightGBM models
        feat_train_df:
            学習時に使った DataFrame
    """
    feature_importance_df = pd.DataFrame()
    for i, model in enumerate(models):
        _df = pd.DataFrame()
        _df['feature_importance'] = model.feature_importances_
        _df['column'] = feat_train_df.columns
        _df['fold'] = i + 1
        feature_importance_df = pd.concat([feature_importance_df, _df], axis=0, ignore_index=True)

    order = feature_importance_df.groupby('column')\
        .sum()[['feature_importance']]\
        .sort_values('feature_importance', ascending=False).index[:50]

    fig, ax = plt.subplots(figsize=(max(6, len(order) * .4), 7))
    sns.boxenplot(data=feature_importance_df, x='column', y='feature_importance', order=order, ax=ax, palette='viridis')
    ax.tick_params(axis='x', rotation=90)
    ax.grid()
    fig.tight_layout()
    return fig, ax

# %%
fig, ax = visualize_importance(models, train_x)

# %%
pred_lgb = np.array([model.predict(test_x.values) for model in models])

# %%
from scipy.stats import mode
pred_lgbs = mode(pred_lgb)[0][0]

# %%
submit_df = pd.DataFrame({'y': pred_lgbs})
submit_df.index.name = 'id'
submit_df.to_csv(emp+'submission.csv')

# %%
np.unique(mode(pred_lgb)[0][0])
# Out:
# array([0, 1, 2, 3, 4, 5, 7])
