# %%
emp = "exp_16_"

# %%
import numpy as np 
import pandas as pd 
import re
import typing as tp

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import string
import lightgbm as lgb
import xgboost as xgb
from tqdm import tqdm

import os
from glob import glob

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics

from collections import Counter
pd.set_option('display.max_columns', 100)
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']


import category_encoders as ce
from sklearn.model_selection import KFold, StratifiedKFold

from xfeat import (SelectCategorical, LabelEncoder, Pipeline, ConcatCombination, SelectNumerical, 
                   ArithmeticCombinations, TargetEncoder, aggregation, GBDTFeatureSelector, GBDTFeatureExplorer)

import warnings

# %%
train_df = pd.read_csv("../train_data.csv")
test_df = pd.read_csv("../test_data.csv")
game_df = pd.read_csv("../game_info.csv")
game_df = game_df.drop('Unnamed: 0',axis=1)

# bool型が面倒なので、先に変換する
bool_list = ["b1", "b2", "b3"]
for i in bool_list:
    train_df[i] = train_df[i]*1
    test_df[i] = test_df[i]*1

# baselineとして、train_dfにしかないデータは削除する。
# 実験のどこかで追加できるように前処理をかける
drop_list = [
    "pitchType", "speed", "ballPositionLabel", "ballX",
    "ballY", "dir", "dist", "battingType", "isOuts"
]
train_df = train_df.drop(drop_list, axis=1)

# %%
from contextlib import contextmanager
from time import time

@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)

# %%
# 前処理前の準備として実施する
train_df["counts"] = train_df[['S', 'B']].apply(lambda x: '{}-{}'.format(x[0], x[1]),axis=1)
test_df["counts"] = test_df[['S', 'B']].apply(lambda x: '{}-{}'.format(x[0], x[1]),axis=1)

# exp4との差
train_df["total_counts"] = train_df[['S', 'B', 'O']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]),axis=1)
test_df["total_counts"] = test_df[['S', 'B', 'O']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]),axis=1)

# exp5との差
train_df["runner_status"] = train_df[['b1', 'b2', 'b3']].apply(lambda x:'{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
test_df["runner_status"] = test_df[['b1', 'b2', 'b3']].apply(lambda x:'{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

# %%
# baseBlock 

class BaseBlock(object):
    def fit(self, input_df, y=None):
        return self.transform(input_df)
    
    def transform(self, input_df):
        raise NotImplementedError()
        
# CountEncoding
class CountEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        self.encoder = ce.CountEncoder()
        self.encoder.fit(input_df[self.cols])
        return self.encoder.transform(input_df[self.cols]).add_prefix("CE_")
    
# OneHotEncoding
class OneHotEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        self.encoder = ce.OneHotEncoder(use_cat_names=True)
        self.encoder.fit(input_df[self.cols])
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        return self.encoder.transform(input_df[self.cols]).add_prefix("OHE_")

# OrdinalEncoding
class OrdinalEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        self.encoder = ce.OrdinalEncoder()
        self.encoder.fit(input_df[self.cols])
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        return self.encoder.transform(input_df[self.cols]).add_prefix("OE_")

# %%
# 前処理の追加をする関数
def get_top_bottom(x):
    if '表' in x:
        return 0
    else:
        return 1

    
def get_inning(input_df):
    output_df = pd.DataFrame()
    
    output_df['top_bottom'] = input_df['inning'].apply(lambda x: get_top_bottom(x))
    output_df['inning_num'] = input_df['inning'].apply(lambda x: re.sub("\\D", "", x))
    
    return output_df


# ピッチャー左対バッター右
def left_vs_right(x, y):
    if x=="L" and y=='R':
        return 1
    else:
        return 0

    
def right_vs_left(x,y):
    if x=='R' and y=='L':
        return 1
    else:
        return 0

    
def get_pvsb(input_df):
    output_df = pd.DataFrame()
    output_df['left_right'] = input_df[['pitcherHand', 'batterHand']].apply(lambda x: left_vs_right(x[0], x[1]),axis=1)
    output_df['right_left'] = input_df[['pitcherHand', 'batterHand']].apply(lambda x: right_vs_left(x[0], x[1]),axis=1)
    
    return output_df


# 6球目以降、yの分布が変化する
def count_after_6(x):
    if x >= 6:
        return 1
    else:
        return 0
    
    
def get_after_6(input_df):
    output_df = pd.DataFrame()
    output_df["get_after_6"] = input_df["totalPitchingCount"].apply(lambda x: count_after_6(x))
    
    return output_df

# %%
# encoding系の処理を行う関数
def get_ce_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    
    cols = [
        'pitcher',
        'pitcherHand',
        'batter',
        'batterHand',
        'inning',
        'counts',
        'total_counts',
        'runner_status'
    ]
    
    encoder = CountEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df.astype(str))
    return output_df

def get_oe_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
        #'pitcher',
        'pitcherHand',
        #'batter',
        'batterHand',
        'inning',
        'counts',
        'total_counts',
        'runner_status'
    ]
    encoder = OrdinalEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df)
    return output_df

def get_ohe_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
       #'pitcher',
        'pitcherHand',
        #'batter',
        'batterHand',
        'inning',
        'counts',
        'total_counts',
        'runner_status'
    ]
    encoder = OneHotEncodingBlock(cols=cols)
    output_df = encoder.fit(_input_df)
    return output_df


# numeric_feature
def create_numeric_feature(input_df):
    use_columns = [
        'totalPitchingCount',
        'B', 'S', 'O','b1', 'b2', 'b3',
    ]

    return input_df[use_columns].copy()

# %%
# 前処理関数を順々に処理していく関数
def to_features(train, test):
    input_df = pd.concat([train, test]).reset_index(drop=True)

    processes = [
        get_oe_features,
        get_ce_features,
        get_ohe_features,
        create_numeric_feature,
        get_inning,
        get_pvsb,
        get_after_6
    ]

    output_df = pd.DataFrame()
    for func in tqdm(processes):
        _df = func(input_df)
        assert len(_df) == len(input_df), func.__name__
        output_df = pd.concat([output_df, _df], axis=1)

    train_x = output_df.iloc[:len(train)] 
    test_x = output_df.iloc[len(train):].reset_index(drop=True)
    return train_x, test_x

# %%
target_data = "y" 

train_x, test_x = to_features(train_df, test_df)
train_ys_for_split = train_df[target_data]
train_ys = train_df[target_data].values
# Out:
#  29%|██▊       | 2/7 [00:00<00:01,  4.58it/s]/home/kengo-fujii/anaconda3/envs/py36/lib/python3.6/site-packages/category_encoders/utils.py:21: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# 100%|██████████| 7/7 [00:01<00:00,  4.64it/s]

# %%
def fit_lgbm(X, y, cv, params: dict=None, verbose: int=50):
    """lightGBM を CrossValidation の枠組みで学習を行なう function"""
    metric_func = f1_score

    # パラメータがないときは、空の dict で置き換える
    if params is None:
        params = {}

    models = []
    # training data の target と同じだけのゼロ配列を用意
    # float にしないと悲しい事件が起こるのでそこだけ注意
    oof_pred = np.zeros_like(y, dtype=np.float)

    for i, (idx_train, idx_valid) in enumerate(cv): 
        # この部分が交差検証のところです。データセットを cv instance によって分割します
        # training data を trian/valid に分割
        x_train, y_train = X[idx_train], y[idx_train]
        x_valid, y_valid = X[idx_valid], y[idx_valid]

        clf = lgb.LGBMClassifier(**params)

        with timer(prefix='fit fold={} '.format(i + 1)):
            clf.fit(x_train, y_train, 
                    eval_set=[(x_valid, y_valid)],  
                    early_stopping_rounds=verbose,
                    verbose=verbose)

        pred_i = clf.predict(x_valid)

        oof_pred[idx_valid] = pred_i
        models.append(clf)

        print(f'Fold {i} Macro-F1: {metric_func(y_valid, pred_i, average="macro") :.4f}')

    score = metric_func(y, oof_pred, average="macro") 
    print('FINISHED | Whole Macro-F1: {:.4f}'.format(score))
    return oof_pred, models

# %%
lgm_params = {  
    "n_estimators": 20000,
    "objective": 'multiclass',
    "num_class":8,
    "learning_rate": 0.01,
    "num_leaves": 36,
    "random_state": 2021,
    "n_jobs": -1,
    "importance_type": "gain",
    'colsample_bytree': .5,
    "reg_lambda": 5,
    "max_depth":7,
    }

fold = KFold(n_splits=5, shuffle=True, random_state=42)
cv = list(fold.split(train_x, train_ys)) # もともとが generator なため明示的に list に変換する

# %%
oof, models = fit_lgbm(train_x.values, train_ys, cv, params=lgm_params)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=0.01113869595673112, reg_alpha=8 will be ignored. Current value: lambda_l1=0.01113869595673112
# [LightGBM] [Warning] bagging_fraction is set=0.5520399476847848, subsample=0.5 will be ignored. Current value: bagging_fraction=0.5520399476847848
# [LightGBM] [Warning] feature_fraction is set=0.4436319472771827, colsample_bytree=0.5 will be ignored. Current value: feature_fraction=0.4436319472771827
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=3 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=8.706009358617911e-07, reg_lambda=2 will be ignored. Current value: lambda_l2=8.706009358617911e-07
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.48151
# [100]	valid_0's multi_logloss: 1.46909
# [150]	valid_0's multi_logloss: 1.46342
# [200]	valid_0's multi_logloss: 1.46011
# [250]	valid_0's multi_logloss: 1.45781
# [300]	valid_0's multi_logloss: 1.45611
# [350]	valid_0's multi_logloss: 1.45475
# [400]	valid_0's multi_logloss: 1.45331
# [450]	valid_0's multi_logloss: 1.45188
# [500]	valid_0's multi_logloss: 1.45067
# [550]	valid_0's multi_logloss: 1.44975
# [600]	valid_0's multi_logloss: 1.44909
# [650]	valid_0's multi_logloss: 1.44836
# [700]	valid_0's multi_logloss: 1.44753
# [750]	valid_0's multi_logloss: 1.44696
# [800]	valid_0's multi_logloss: 1.44667
# [850]	valid_0's multi_logloss: 1.44623
# [900]	valid_0's multi_logloss: 1.44547
# [950]	valid_0's multi_logloss: 1.44473
# [1000]	valid_0's multi_logloss: 1.44432
# [1050]	valid_0's multi_logloss: 1.44396
# [1100]	valid_0's multi_logloss: 1.44374
# [1150]	valid_0's multi_logloss: 1.44367
# [1200]	valid_0's multi_logloss: 1.44324
# [1250]	valid_0's multi_logloss: 1.44271
# [1300]	valid_0's multi_logloss: 1.44258
# [1350]	valid_0's multi_logloss: 1.44242
# [1400]	valid_0's multi_logloss: 1.44204
# [1450]	valid_0's multi_logloss: 1.44168
# [1500]	valid_0's multi_logloss: 1.44152
# [1550]	valid_0's multi_logloss: 1.44116
# [1600]	valid_0's multi_logloss: 1.44129
# Early stopping, best iteration is:
# [1557]	valid_0's multi_logloss: 1.4411
# fit fold=1 6.431[s]
# Fold 0 Macro-F1: 0.2065
# [LightGBM] [Warning] lambda_l1 is set=0.01113869595673112, reg_alpha=8 will be ignored. Current value: lambda_l1=0.01113869595673112
# [LightGBM] [Warning] bagging_fraction is set=0.5520399476847848, subsample=0.5 will be ignored. Current value: bagging_fraction=0.5520399476847848
# [LightGBM] [Warning] feature_fraction is set=0.4436319472771827, colsample_bytree=0.5 will be ignored. Current value: feature_fraction=0.4436319472771827
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=3 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=8.706009358617911e-07, reg_lambda=2 will be ignored. Current value: lambda_l2=8.706009358617911e-07
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.45468
# [100]	valid_0's multi_logloss: 1.44365
# [150]	valid_0's multi_logloss: 1.43882
# [200]	valid_0's multi_logloss: 1.43648
# [250]	valid_0's multi_logloss: 1.43471
# [300]	valid_0's multi_logloss: 1.43344
# [350]	valid_0's multi_logloss: 1.43223
# [400]	valid_0's multi_logloss: 1.43163
# [450]	valid_0's multi_logloss: 1.43086
# [500]	valid_0's multi_logloss: 1.43023
# [550]	valid_0's multi_logloss: 1.4296
# [600]	valid_0's multi_logloss: 1.42868
# [650]	valid_0's multi_logloss: 1.42822
# [700]	valid_0's multi_logloss: 1.42748
# [750]	valid_0's multi_logloss: 1.42693
# [800]	valid_0's multi_logloss: 1.42636
# [850]	valid_0's multi_logloss: 1.42563
# [900]	valid_0's multi_logloss: 1.42526
# [950]	valid_0's multi_logloss: 1.42483
# [1000]	valid_0's multi_logloss: 1.42409
# [1050]	valid_0's multi_logloss: 1.42328
# [1100]	valid_0's multi_logloss: 1.42311
# [1150]	valid_0's multi_logloss: 1.42286
# [1200]	valid_0's multi_logloss: 1.42252
# [1250]	valid_0's multi_logloss: 1.4221
# [1300]	valid_0's multi_logloss: 1.42185
# [1350]	valid_0's multi_logloss: 1.42117
# [1400]	valid_0's multi_logloss: 1.42103
# [1450]	valid_0's multi_logloss: 1.42082
# [1500]	valid_0's multi_logloss: 1.4208
# Early stopping, best iteration is:
# [1475]	valid_0's multi_logloss: 1.42069
# fit fold=2 6.015[s]
# Fold 1 Macro-F1: 0.2344
# [LightGBM] [Warning] lambda_l1 is set=0.01113869595673112, reg_alpha=8 will be ignored. Current value: lambda_l1=0.01113869595673112
# [LightGBM] [Warning] bagging_fraction is set=0.5520399476847848, subsample=0.5 will be ignored. Current value: bagging_fraction=0.5520399476847848
# [LightGBM] [Warning] feature_fraction is set=0.4436319472771827, colsample_bytree=0.5 will be ignored. Current value: feature_fraction=0.4436319472771827
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=3 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=8.706009358617911e-07, reg_lambda=2 will be ignored. Current value: lambda_l2=8.706009358617911e-07
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46421
# [100]	valid_0's multi_logloss: 1.45205
# [150]	valid_0's multi_logloss: 1.44615
# [200]	valid_0's multi_logloss: 1.44333
# [250]	valid_0's multi_logloss: 1.44156
# [300]	valid_0's multi_logloss: 1.43978
# [350]	valid_0's multi_logloss: 1.43915
# [400]	valid_0's multi_logloss: 1.4381
# [450]	valid_0's multi_logloss: 1.43788
# [500]	valid_0's multi_logloss: 1.43703
# [550]	valid_0's multi_logloss: 1.4371
# Early stopping, best iteration is:
# [514]	valid_0's multi_logloss: 1.43688
# fit fold=3 2.289[s]
# Fold 2 Macro-F1: 0.1710
# [LightGBM] [Warning] lambda_l1 is set=0.01113869595673112, reg_alpha=8 will be ignored. Current value: lambda_l1=0.01113869595673112
# [LightGBM] [Warning] bagging_fraction is set=0.5520399476847848, subsample=0.5 will be ignored. Current value: bagging_fraction=0.5520399476847848
# [LightGBM] [Warning] feature_fraction is set=0.4436319472771827, colsample_bytree=0.5 will be ignored. Current value: feature_fraction=0.4436319472771827
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=3 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=8.706009358617911e-07, reg_lambda=2 will be ignored. Current value: lambda_l2=8.706009358617911e-07
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.47762
# [100]	valid_0's multi_logloss: 1.46556
# [150]	valid_0's multi_logloss: 1.45981
# [200]	valid_0's multi_logloss: 1.45597
# [250]	valid_0's multi_logloss: 1.45364
# [300]	valid_0's multi_logloss: 1.45175
# [350]	valid_0's multi_logloss: 1.45034
# [400]	valid_0's multi_logloss: 1.44935
# [450]	valid_0's multi_logloss: 1.44831
# [500]	valid_0's multi_logloss: 1.44719
# [550]	valid_0's multi_logloss: 1.44576
# [600]	valid_0's multi_logloss: 1.44491
# [650]	valid_0's multi_logloss: 1.44406
# [700]	valid_0's multi_logloss: 1.44317
# [750]	valid_0's multi_logloss: 1.44206
# [800]	valid_0's multi_logloss: 1.44114
# [850]	valid_0's multi_logloss: 1.44053
# [900]	valid_0's multi_logloss: 1.43965
# [950]	valid_0's multi_logloss: 1.43904
# [1000]	valid_0's multi_logloss: 1.43881
# [1050]	valid_0's multi_logloss: 1.43816
# [1100]	valid_0's multi_logloss: 1.43742
# [1150]	valid_0's multi_logloss: 1.43685
# [1200]	valid_0's multi_logloss: 1.43651
# [1250]	valid_0's multi_logloss: 1.43599
# [1300]	valid_0's multi_logloss: 1.43573
# [1350]	valid_0's multi_logloss: 1.43553
# [1400]	valid_0's multi_logloss: 1.43522
# [1450]	valid_0's multi_logloss: 1.43468
# [1500]	valid_0's multi_logloss: 1.43434
# Early stopping, best iteration is:
# [1489]	valid_0's multi_logloss: 1.43418
# fit fold=4 6.014[s]
# Fold 3 Macro-F1: 0.1838
# [LightGBM] [Warning] lambda_l1 is set=0.01113869595673112, reg_alpha=8 will be ignored. Current value: lambda_l1=0.01113869595673112
# [LightGBM] [Warning] bagging_fraction is set=0.5520399476847848, subsample=0.5 will be ignored. Current value: bagging_fraction=0.5520399476847848
# [LightGBM] [Warning] feature_fraction is set=0.4436319472771827, colsample_bytree=0.5 will be ignored. Current value: feature_fraction=0.4436319472771827
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=3 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=8.706009358617911e-07, reg_lambda=2 will be ignored. Current value: lambda_l2=8.706009358617911e-07
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.44838
# [100]	valid_0's multi_logloss: 1.43738
# [150]	valid_0's multi_logloss: 1.43295
# [200]	valid_0's multi_logloss: 1.42979
# [250]	valid_0's multi_logloss: 1.42849
# [300]	valid_0's multi_logloss: 1.42761
# [350]	valid_0's multi_logloss: 1.4266
# [400]	valid_0's multi_logloss: 1.42621
# [450]	valid_0's multi_logloss: 1.42561
# [500]	valid_0's multi_logloss: 1.4253
# [550]	valid_0's multi_logloss: 1.42484
# [600]	valid_0's multi_logloss: 1.42416
# [650]	valid_0's multi_logloss: 1.42369
# [700]	valid_0's multi_logloss: 1.42348
# [750]	valid_0's multi_logloss: 1.42309
# [800]	valid_0's multi_logloss: 1.4226
# [850]	valid_0's multi_logloss: 1.42229
# [900]	valid_0's multi_logloss: 1.42177
# [950]	valid_0's multi_logloss: 1.42117
# [1000]	valid_0's multi_logloss: 1.42096
# [1050]	valid_0's multi_logloss: 1.42091
# [1100]	valid_0's multi_logloss: 1.42068
# [1150]	valid_0's multi_logloss: 1.41994
# [1200]	valid_0's multi_logloss: 1.41963
# [1250]	valid_0's multi_logloss: 1.41926
# [1300]	valid_0's multi_logloss: 1.41892
# [1350]	valid_0's multi_logloss: 1.41859
# [1400]	valid_0's multi_logloss: 1.41833
# [1450]	valid_0's multi_logloss: 1.41822
# [1500]	valid_0's multi_logloss: 1.41828
# [1550]	valid_0's multi_logloss: 1.41803
# [1600]	valid_0's multi_logloss: 1.41803
# Early stopping, best iteration is:
# [1577]	valid_0's multi_logloss: 1.4178
# fit fold=5 6.585[s]
# Fold 4 Macro-F1: 0.1736
# FINISHED | Whole Macro-F1: 0.2059

# %%
def visualize_importance(models, feat_train_df):
    """lightGBM の model 配列の feature importance を plot する
    CVごとのブレを boxen plot として表現します.

    args:
        models:
            List of lightGBM models
        feat_train_df:
            学習時に使った DataFrame
    """
    feature_importance_df = pd.DataFrame()
    for i, model in enumerate(models):
        _df = pd.DataFrame()
        _df['feature_importance'] = model.feature_importances_
        _df['column'] = feat_train_df.columns
        _df['fold'] = i + 1
        feature_importance_df = pd.concat([feature_importance_df, _df], axis=0, ignore_index=True)

    order = feature_importance_df.groupby('column')\
        .sum()[['feature_importance']]\
        .sort_values('feature_importance', ascending=False).index[:50]

    fig, ax = plt.subplots(figsize=(max(6, len(order) * .4), 7))
    sns.boxenplot(data=feature_importance_df, x='column', y='feature_importance', order=order, ax=ax, palette='viridis')
    ax.tick_params(axis='x', rotation=90)
    ax.grid()
    fig.tight_layout()
    return fig, ax

# %%
fig, ax = visualize_importance(models, train_x)

# %%
pred_lgb = np.array([model.predict(test_x.values) for model in models])

# %%
from scipy.stats import mode
pred_lgbs = mode(pred_lgb)[0][0]

# %%
submit_df = pd.DataFrame({'y': pred_lgbs})
submit_df.index.name = 'id'
submit_df.to_csv(emp+'submission.csv')
