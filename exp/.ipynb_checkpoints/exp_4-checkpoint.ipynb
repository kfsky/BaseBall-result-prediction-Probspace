# %%
emp = "exp_3_"

# %%
import numpy as np 
import pandas as pd 
import re
import typing as tp

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import string
import lightgbm as lgb
import xgboost as xgb
from tqdm import tqdm

import os
from glob import glob

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics

from collections import Counter
pd.set_option('display.max_columns', 100)
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']


import category_encoders as ce
from sklearn.model_selection import KFold, StratifiedKFold

from xfeat import (SelectCategorical, LabelEncoder, Pipeline, ConcatCombination, SelectNumerical, 
                   ArithmeticCombinations, TargetEncoder, aggregation, GBDTFeatureSelector, GBDTFeatureExplorer)

import warnings

# %%
train_df = pd.read_csv("../train_data.csv")
test_df = pd.read_csv("../test_data.csv")
game_df = pd.read_csv("../game_info.csv")
game_df = game_df.drop('Unnamed: 0',axis=1)

# bool型が面倒なので、先に変換する
bool_list = ["b1", "b2", "b3"]
for i in bool_list:
    train_df[i] = train_df[i]*1
    test_df[i] = test_df[i]*1

# baselineとして、train_dfにしかないデータは削除する。
# 実験のどこかで追加できるように前処理をかける
drop_list = [
    "pitchType", "speed", "ballPositionLabel", "ballX",
    "ballY", "dir", "dist", "battingType", "isOuts"
]
train_df = train_df.drop(drop_list, axis=1)

print('before')
print(train_df.shape)
print(test_df.shape)

# game_infoをmerge
train_df = pd.merge(train_df, game_df, on='gameID', how='left')
test_df = pd.merge(test_df, game_df, on='gameID', how='left')

print('after')
print(train_df.shape)
print(test_df.shape)
# Out:
# before
# (20400, 15)
# (33808, 14)
# after
# (20400, 22)
# (33808, 21)

# %%
from contextlib import contextmanager
from time import time

@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)

# %%
# baseBlock 

class BaseBlock(object):
    def fit(self, input_df, y=None):
        return self.transform(input_df)
    
    def transform(self, input_df):
        raise NotImplementedError()
        
# CountEncoding
class CountEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        self.encoder = ce.CountEncoder()
        self.encoder.fit(input_df[self.cols])
        return self.encoder.transform(input_df[self.cols]).add_prefix("CE_")
    
# OneHotEncoding
class OneHotEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        self.encoder = ce.OneHotEncoder(use_cat_names=True)
        self.encoder.fit(input_df[self.cols])
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        return self.encoder.transform(input_df[self.cols]).add_prefix("OHE_")

# OrdinalEncoding
class OrdinalEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        self.encoder = ce.OrdinalEncoder()
        self.encoder.fit(input_df[self.cols])
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        return self.encoder.transform(input_df[self.cols]).add_prefix("OE_")

# %%
# 前処理の追加をする関数
def get_top_bottom(x):
    if '表' in x:
        return 0
    else:
        return 1

def get_inning(input_df):
    output_df = pd.DataFrame()
    
    output_df['top_bottom'] = input_df['inning'].apply(lambda x: get_top_bottom(x))
    output_df['inning_num'] = input_df['inning'].apply(lambda x: re.sub("\\D", "", x))
    
    return output_df

# ピッチャー左対バッター右
def left_vs_right(x, y):
    if x=="L" and y=='R':
        return 1
    else:
        return 0

def right_vs_left(x,y):
    if x=='R' and y=='L':
        return 1
    else:
        return 0

def get_pvsb(input_df):
    output_df = pd.DataFrame()
    output_df['left_right'] = input_df[['pitcherHand', 'batterHand']].apply(lambda x: left_vs_right(x[0], x[1]),axis=1)
    output_df['right_left'] = input_df[['pitcherHand', 'batterHand']].apply(lambda x: right_vs_left(x[0], x[1]),axis=1)
    
    return output_df

# %%
# encoding系の処理を行う関数
def get_ce_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    
    cols = [
        'pitcher',
        'pitcherHand',
        'batter',
        'batterHand',
        'bottomTeam',
        'topTeam',
        'place',
        'inning'
    ]
    
    encoder = CountEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df.astype(str))
    return output_df

def get_oe_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
        'pitcher',
        'pitcherHand',
        'batter',
        'batterHand',
        'bottomTeam',
        'topTeam',
        'place',
        'inning'
    ]
    encoder = OrdinalEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df)
    return output_df

def get_ohe_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
       'pitcher',
        'pitcherHand',
        'batter',
        'batterHand',
        'bottomTeam',
        'topTeam',
        'place',
        'inning'
    ]
    encoder = OneHotEncodingBlock(cols=cols)
    output_df = encoder.fit(_input_df)
    return output_df


# numeric_feature
def create_numeric_feature(input_df):
    use_columns = [
        'totalPitchingCount',
        'B', 'S', 'O','b1', 'b2', 'b3',
    ]

    return input_df[use_columns].copy()

# %%
# 前処理関数を順々に処理していく関数
def to_features(train, test):
    input_df = pd.concat([train, test]).reset_index(drop=True)

    processes = [
        get_oe_features,
        get_ce_features,
        get_ohe_features,
        create_numeric_feature,
        get_inning,
        get_pvsb
    ]

    output_df = pd.DataFrame()
    for func in tqdm(processes):
        _df = func(input_df)
        assert len(_df) == len(input_df), func.__name__
        output_df = pd.concat([output_df, _df], axis=1)

    train_x = output_df.iloc[:len(train)] 
    test_x = output_df.iloc[len(train):].reset_index(drop=True)
    return train_x, test_x

# %%
target_data = "y" 

train_x, test_x = to_features(train_df, test_df)
train_ys_for_split = train_df[target_data]
train_ys = train_df[target_data].values
# Out:
#  33%|███▎      | 2/6 [00:00<00:01,  3.83it/s]/home/kengo-fujii/anaconda3/envs/py36/lib/python3.6/site-packages/category_encoders/utils.py:21: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# 100%|██████████| 6/6 [00:04<00:00,  1.43it/s]

# %%
def fit_lgbm(X, y, cv, params: dict=None, verbose: int=50):
    """lightGBM を CrossValidation の枠組みで学習を行なう function"""
    metric_func = f1_score

    # パラメータがないときは、空の dict で置き換える
    if params is None:
        params = {}

    models = []
    # training data の target と同じだけのゼロ配列を用意
    # float にしないと悲しい事件が起こるのでそこだけ注意
    oof_pred = np.zeros_like(y, dtype=np.float)

    for i, (idx_train, idx_valid) in enumerate(cv): 
        # この部分が交差検証のところです。データセットを cv instance によって分割します
        # training data を trian/valid に分割
        x_train, y_train = X[idx_train], y[idx_train]
        x_valid, y_valid = X[idx_valid], y[idx_valid]

        clf = lgb.LGBMClassifier(**params)

        with timer(prefix='fit fold={} '.format(i + 1)):
            clf.fit(x_train, y_train, 
                    eval_set=[(x_valid, y_valid)],  
                    early_stopping_rounds=verbose,
                    verbose=verbose)

        pred_i = clf.predict(x_valid)

        oof_pred[idx_valid] = pred_i
        models.append(clf)

        print(f'Fold {i} Macro-F1: {metric_func(y_valid, pred_i, average="macro") :.4f}')

    score = metric_func(y, oof_pred, average="macro") 
    print('FINISHED | Whole Macro-F1: {:.4f}'.format(score))
    return oof_pred, models

# %%
lgm_params = {  
    "n_estimators": 20000,
    "objective": 'multiclass',
    "num_class":8,
    "learning_rate": 0.01,
    "num_leaves": 36,
    "random_state": 2021,
    "n_jobs": -1,
    "importance_type": "gain",
    'colsample_bytree': .5,
    "reg_lambda": 5,
    "max_depth":7,
    }

fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv = list(fold.split(train_x, train_ys)) # もともとが generator なため明示的に list に変換する

# %%
oof, models = fit_lgbm(train_x.values, train_ys, cv, params=lgm_params)
# Out:
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.48377
# [100]	valid_0's multi_logloss: 1.46713
# [150]	valid_0's multi_logloss: 1.45692
# [200]	valid_0's multi_logloss: 1.45033
# [250]	valid_0's multi_logloss: 1.44616
# [300]	valid_0's multi_logloss: 1.44364
# [350]	valid_0's multi_logloss: 1.44169
# [400]	valid_0's multi_logloss: 1.44021
# [450]	valid_0's multi_logloss: 1.43882
# [500]	valid_0's multi_logloss: 1.43775
# [550]	valid_0's multi_logloss: 1.43672
# [600]	valid_0's multi_logloss: 1.43565
# [650]	valid_0's multi_logloss: 1.43471
# [700]	valid_0's multi_logloss: 1.4338
# [750]	valid_0's multi_logloss: 1.4329
# [800]	valid_0's multi_logloss: 1.43224
# [850]	valid_0's multi_logloss: 1.43161
# [900]	valid_0's multi_logloss: 1.43096
# [950]	valid_0's multi_logloss: 1.43056
# [1000]	valid_0's multi_logloss: 1.43011
# [1050]	valid_0's multi_logloss: 1.42967
# [1100]	valid_0's multi_logloss: 1.42914
# [1150]	valid_0's multi_logloss: 1.4288
# [1200]	valid_0's multi_logloss: 1.4284
# [1250]	valid_0's multi_logloss: 1.42805
# [1300]	valid_0's multi_logloss: 1.42781
# [1350]	valid_0's multi_logloss: 1.42764
# [1400]	valid_0's multi_logloss: 1.42748
# [1450]	valid_0's multi_logloss: 1.42714
# [1500]	valid_0's multi_logloss: 1.42687
# [1550]	valid_0's multi_logloss: 1.4266
# [1600]	valid_0's multi_logloss: 1.42626
# [1650]	valid_0's multi_logloss: 1.42596
# [1700]	valid_0's multi_logloss: 1.42592
# Early stopping, best iteration is:
# [1665]	valid_0's multi_logloss: 1.42589
# fit fold=1 12.727[s]
# Fold 0 Macro-F1: 0.2139
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.45893
# [100]	valid_0's multi_logloss: 1.44237
# [150]	valid_0's multi_logloss: 1.43312
# [200]	valid_0's multi_logloss: 1.42723
# [250]	valid_0's multi_logloss: 1.42329
# [300]	valid_0's multi_logloss: 1.42076
# [350]	valid_0's multi_logloss: 1.41912
# [400]	valid_0's multi_logloss: 1.41795
# [450]	valid_0's multi_logloss: 1.41704
# [500]	valid_0's multi_logloss: 1.41618
# [550]	valid_0's multi_logloss: 1.41566
# [600]	valid_0's multi_logloss: 1.4152
# [650]	valid_0's multi_logloss: 1.41453
# [700]	valid_0's multi_logloss: 1.41411
# [750]	valid_0's multi_logloss: 1.41374
# [800]	valid_0's multi_logloss: 1.41333
# [850]	valid_0's multi_logloss: 1.41304
# [900]	valid_0's multi_logloss: 1.41275
# [950]	valid_0's multi_logloss: 1.41235
# [1000]	valid_0's multi_logloss: 1.41205
# [1050]	valid_0's multi_logloss: 1.41178
# [1100]	valid_0's multi_logloss: 1.41129
# [1150]	valid_0's multi_logloss: 1.41105
# [1200]	valid_0's multi_logloss: 1.41086
# [1250]	valid_0's multi_logloss: 1.41058
# [1300]	valid_0's multi_logloss: 1.41035
# [1350]	valid_0's multi_logloss: 1.41026
# [1400]	valid_0's multi_logloss: 1.4102
# [1450]	valid_0's multi_logloss: 1.41018
# [1500]	valid_0's multi_logloss: 1.40995
# [1550]	valid_0's multi_logloss: 1.4097
# [1600]	valid_0's multi_logloss: 1.40949
# [1650]	valid_0's multi_logloss: 1.40938
# [1700]	valid_0's multi_logloss: 1.40916
# [1750]	valid_0's multi_logloss: 1.40915
# [1800]	valid_0's multi_logloss: 1.40896
# [1850]	valid_0's multi_logloss: 1.40878
# [1900]	valid_0's multi_logloss: 1.40872
# [1950]	valid_0's multi_logloss: 1.40864
# [2000]	valid_0's multi_logloss: 1.40847
# [2050]	valid_0's multi_logloss: 1.40832
# [2100]	valid_0's multi_logloss: 1.40814
# [2150]	valid_0's multi_logloss: 1.40814
# [2200]	valid_0's multi_logloss: 1.408
# [2250]	valid_0's multi_logloss: 1.4078
# [2300]	valid_0's multi_logloss: 1.40765
# Early stopping, best iteration is:
# [2296]	valid_0's multi_logloss: 1.40762
# fit fold=2 17.613[s]
# Fold 1 Macro-F1: 0.2428
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46775
# [100]	valid_0's multi_logloss: 1.45121
# [150]	valid_0's multi_logloss: 1.44161
# [200]	valid_0's multi_logloss: 1.4362
# [250]	valid_0's multi_logloss: 1.43242
# [300]	valid_0's multi_logloss: 1.43005
# [350]	valid_0's multi_logloss: 1.42857
# [400]	valid_0's multi_logloss: 1.42741
# [450]	valid_0's multi_logloss: 1.42633
# [500]	valid_0's multi_logloss: 1.42571
# [550]	valid_0's multi_logloss: 1.42499
# [600]	valid_0's multi_logloss: 1.4246
# [650]	valid_0's multi_logloss: 1.42399
# [700]	valid_0's multi_logloss: 1.42356
# [750]	valid_0's multi_logloss: 1.42307
# [800]	valid_0's multi_logloss: 1.42281
# [850]	valid_0's multi_logloss: 1.42252
# [900]	valid_0's multi_logloss: 1.42213
# [950]	valid_0's multi_logloss: 1.42185
# [1000]	valid_0's multi_logloss: 1.42158
# [1050]	valid_0's multi_logloss: 1.42125
# [1100]	valid_0's multi_logloss: 1.42099
# [1150]	valid_0's multi_logloss: 1.42069
# [1200]	valid_0's multi_logloss: 1.42043
# [1250]	valid_0's multi_logloss: 1.42028
# [1300]	valid_0's multi_logloss: 1.42014
# [1350]	valid_0's multi_logloss: 1.42005
# [1400]	valid_0's multi_logloss: 1.41998
# [1450]	valid_0's multi_logloss: 1.41991
# [1500]	valid_0's multi_logloss: 1.41974
# [1550]	valid_0's multi_logloss: 1.41964
# [1600]	valid_0's multi_logloss: 1.41956
# [1650]	valid_0's multi_logloss: 1.41946
# Early stopping, best iteration is:
# [1626]	valid_0's multi_logloss: 1.41942
# fit fold=3 12.381[s]
# Fold 2 Macro-F1: 0.2219
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.48016
# [100]	valid_0's multi_logloss: 1.46246
# [150]	valid_0's multi_logloss: 1.45203
# [200]	valid_0's multi_logloss: 1.4453
# [250]	valid_0's multi_logloss: 1.44138
# [300]	valid_0's multi_logloss: 1.43848
# [350]	valid_0's multi_logloss: 1.43669
# [400]	valid_0's multi_logloss: 1.43529
# [450]	valid_0's multi_logloss: 1.43447
# [500]	valid_0's multi_logloss: 1.43373
# [550]	valid_0's multi_logloss: 1.43302
# [600]	valid_0's multi_logloss: 1.43249
# [650]	valid_0's multi_logloss: 1.43207
# [700]	valid_0's multi_logloss: 1.4317
# [750]	valid_0's multi_logloss: 1.43133
# [800]	valid_0's multi_logloss: 1.43068
# [850]	valid_0's multi_logloss: 1.43025
# [900]	valid_0's multi_logloss: 1.42981
# [950]	valid_0's multi_logloss: 1.42962
# [1000]	valid_0's multi_logloss: 1.42949
# [1050]	valid_0's multi_logloss: 1.42943
# [1100]	valid_0's multi_logloss: 1.42917
# [1150]	valid_0's multi_logloss: 1.4291
# [1200]	valid_0's multi_logloss: 1.42884
# [1250]	valid_0's multi_logloss: 1.42872
# Early stopping, best iteration is:
# [1244]	valid_0's multi_logloss: 1.42872
# fit fold=4 11.192[s]
# Fold 3 Macro-F1: 0.1716
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.44893
# [100]	valid_0's multi_logloss: 1.43402
# [150]	valid_0's multi_logloss: 1.42518
# [200]	valid_0's multi_logloss: 1.42018
# [250]	valid_0's multi_logloss: 1.41678
# [300]	valid_0's multi_logloss: 1.41471
# [350]	valid_0's multi_logloss: 1.41319
# [400]	valid_0's multi_logloss: 1.41196
# [450]	valid_0's multi_logloss: 1.41097
# [500]	valid_0's multi_logloss: 1.41026
# [550]	valid_0's multi_logloss: 1.40986
# [600]	valid_0's multi_logloss: 1.40942
# [650]	valid_0's multi_logloss: 1.40903
# [700]	valid_0's multi_logloss: 1.40894
# [750]	valid_0's multi_logloss: 1.40849
# [800]	valid_0's multi_logloss: 1.40829
# [850]	valid_0's multi_logloss: 1.40797
# [900]	valid_0's multi_logloss: 1.4077
# [950]	valid_0's multi_logloss: 1.40763
# [1000]	valid_0's multi_logloss: 1.40733
# [1050]	valid_0's multi_logloss: 1.40707
# [1100]	valid_0's multi_logloss: 1.40695
# [1150]	valid_0's multi_logloss: 1.40672
# [1200]	valid_0's multi_logloss: 1.40646
# [1250]	valid_0's multi_logloss: 1.4063
# [1300]	valid_0's multi_logloss: 1.40616
# [1350]	valid_0's multi_logloss: 1.40592
# [1400]	valid_0's multi_logloss: 1.4057
# [1450]	valid_0's multi_logloss: 1.40555
# [1500]	valid_0's multi_logloss: 1.40544
# [1550]	valid_0's multi_logloss: 1.40534
# [1600]	valid_0's multi_logloss: 1.40522
# Early stopping, best iteration is:
# [1565]	valid_0's multi_logloss: 1.4052
# fit fold=5 13.346[s]
# Fold 4 Macro-F1: 0.1600
# FINISHED | Whole Macro-F1: 0.2098

# %%
def visualize_importance(models, feat_train_df):
    """lightGBM の model 配列の feature importance を plot する
    CVごとのブレを boxen plot として表現します.

    args:
        models:
            List of lightGBM models
        feat_train_df:
            学習時に使った DataFrame
    """
    feature_importance_df = pd.DataFrame()
    for i, model in enumerate(models):
        _df = pd.DataFrame()
        _df['feature_importance'] = model.feature_importances_
        _df['column'] = feat_train_df.columns
        _df['fold'] = i + 1
        feature_importance_df = pd.concat([feature_importance_df, _df], axis=0, ignore_index=True)

    order = feature_importance_df.groupby('column')\
        .sum()[['feature_importance']]\
        .sort_values('feature_importance', ascending=False).index[:50]

    fig, ax = plt.subplots(figsize=(max(6, len(order) * .4), 7))
    sns.boxenplot(data=feature_importance_df, x='column', y='feature_importance', order=order, ax=ax, palette='viridis')
    ax.tick_params(axis='x', rotation=90)
    ax.grid()
    fig.tight_layout()
    return fig, ax

# %%
fig, ax = visualize_importance(models, train_x)

# %%
pred_lgb = np.array([model.predict(test_x.values) for model in models])

# %%
from scipy.stats import mode
pred_lgbs = mode(pred_lgb)[0][0]

# %%
submit_df = pd.DataFrame({'y': pred_lgbs})
submit_df.index.name = 'id'
submit_df.to_csv(emp+'submission.csv')
