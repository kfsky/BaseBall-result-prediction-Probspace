# %%
emp = "exp_24_"

# %%
import numpy as np 
import pandas as pd 
import re
import typing as tp

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import string
import lightgbm as lgb
import xgboost as xgb
from tqdm import tqdm

import os
from glob import glob

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics

from collections import Counter
pd.set_option('display.max_columns', 100)
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']


import category_encoders as ce
from sklearn.model_selection import KFold, StratifiedKFold

from xfeat import (SelectCategorical, LabelEncoder, Pipeline, ConcatCombination, SelectNumerical, 
                   ArithmeticCombinations, TargetEncoder, aggregation, GBDTFeatureSelector, GBDTFeatureExplorer)

import warnings

# %%
train_df = pd.read_csv("../train_data.csv")
test_df = pd.read_csv("../test_data.csv")
game_df = pd.read_csv("../game_info.csv")
game_df = game_df.drop('Unnamed: 0',axis=1)

# bool型が面倒なので、先に変換する
bool_list = ["b1", "b2", "b3"]
for i in bool_list:
    train_df[i] = train_df[i]*1
    test_df[i] = test_df[i]*1

# baselineとして、train_dfにしかないデータは削除する。
# 実験のどこかで追加できるように前処理をかける
drop_list = [
    "pitchType", "speed", "ballPositionLabel", "ballX",
    "ballY", "dir", "dist", "battingType", "isOuts"
]
train_df = train_df.drop(drop_list, axis=1)

# %%
from contextlib import contextmanager
from time import time

@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)

# %%
# 前処理前の準備として実施する
train_df["counts"] = train_df[['S', 'B']].apply(lambda x: '{}-{}'.format(x[0], x[1]),axis=1)
test_df["counts"] = test_df[['S', 'B']].apply(lambda x: '{}-{}'.format(x[0], x[1]),axis=1)

# exp4との差
train_df["total_counts"] = train_df[['S', 'B', 'O']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]),axis=1)
test_df["total_counts"] = test_df[['S', 'B', 'O']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]),axis=1)

# exp5との差
train_df["runner_status"] = train_df[['b1', 'b2', 'b3']].apply(lambda x:'{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
test_df["runner_status"] = test_df[['b1', 'b2', 'b3']].apply(lambda x:'{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

# %%
# baseBlock 

class BaseBlock(object):
    def fit(self, input_df, y=None):
        return self.transform(input_df)
    
    def transform(self, input_df):
        raise NotImplementedError()
        
# CountEncoding
class CountEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        self.encoder = ce.CountEncoder()
        self.encoder.fit(input_df[self.cols])
        return self.encoder.transform(input_df[self.cols]).add_prefix("CE_")
    
# OneHotEncoding
class OneHotEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        self.encoder = ce.OneHotEncoder(use_cat_names=True)
        self.encoder.fit(input_df[self.cols])
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        return self.encoder.transform(input_df[self.cols]).add_prefix("OHE_")

# OrdinalEncoding
class OrdinalEncodingBlock(BaseBlock):
    def __init__(self, cols):
        self.cols = cols
        self.encoder = None
        
    def fit(self, input_df, y=None):
        self.encoder = ce.OrdinalEncoder()
        self.encoder.fit(input_df[self.cols])
        return self.transform(input_df[self.cols])
    
    def transform(self, input_df):
        return self.encoder.transform(input_df[self.cols]).add_prefix("OE_")

# %%
# 前処理の追加をする関数
def get_top_bottom(x):
    if '表' in x:
        return 0
    else:
        return 1

def get_inning(input_df):
    output_df = pd.DataFrame()
    
    output_df['top_bottom'] = input_df['inning'].apply(lambda x: get_top_bottom(x))
    output_df['inning_num'] = input_df['inning'].apply(lambda x: re.sub("\\D", "", x))
    
    return output_df

# ピッチャー左対バッター右
def left_vs_right(x, y):
    if x=="L" and y=='R':
        return 1
    else:
        return 0

def right_vs_left(x,y):
    if x=='R' and y=='L':
        return 1
    else:
        return 0

def get_pvsb(input_df):
    output_df = pd.DataFrame()
    output_df['left_right'] = input_df[['pitcherHand', 'batterHand']].apply(lambda x: left_vs_right(x[0], x[1]),axis=1)
    output_df['right_left'] = input_df[['pitcherHand', 'batterHand']].apply(lambda x: right_vs_left(x[0], x[1]),axis=1)
    
    return output_df

def get_agg_inning(input_df):
    cols = "inning"
    
    output_df = pd.DataFrame()
    output_df, agg_cols = aggregation(input_df,
                                     group_key = cols,
                                     group_values = ["totalPitchingCount"],
                                     agg_methods = ["max","median", "mean", "std", "var"]
                                     )
    
    return output_df[agg_cols]


def get_agg_runner_status(input_df):
    cols = "runner_status"
    
    output_df = pd.DataFrame()
    output_df, agg_cols = aggregation(input_df,
                                     group_key=cols,
                                     group_values=["totalPitchingCount"],
                                     agg_methods = ["max", "median", "mean", "std", "var"]
                                     )
    
    return output_df[agg_cols]


def full_count_search(x,y):
    if x==3 and y==2:
        return 1
    else:
        return 0


def get_full_count(input_df):
    output_df = pd.DataFrame()
    
    output_df["full_count"] = input_df[["B", "S"]].apply(lambda x: full_count_search(x[0], x[1]), axis=1)
    
    return output_df

# 対戦カードの情報を追加する
def get_match(input_df):
    _input_df = pd.merge(input_df, game_df, on="gameID", how="left")
    _input_df["match"] = _input_df["topTeam"] + "vs" + _input_df["bottomTeam"]
    
    cols = [
        "match"
    ]
    
    encoder = CountEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df.astype(str))
    
    return output_df

# セ・パの情報を入れる（追加で日本シリーズかどうかも判定）
def search_central_league(x, y):
    central_team = ['巨人', 'DeNA','ヤクルト', '広島', '中日', '阪神']
    if x in central_team and y in central_team:
        return 1
    else:
        return 0
    
#n日本シリーズのデータがtestにしかないから、意味ない？
def search_japan_series(x, y):
    card_team = ['ソフトバンク', '巨人']
    if x in card_team and y in card_team:
        return 1
    elif y in card_team and x in card_team:
        return 1
    else:
        return 0
    
# 判定結果を特徴量に
def get_league(input_df):
    _input_df = pd.merge(input_df, game_df, on="gameID", how="left")
    output_df = pd.DataFrame()
    
    output_df["league"] = _input_df[["topTeam", "bottomTeam"]].apply(lambda x: search_central_league(x[0], x[1]), axis=1)
    #output_df["japan_series"] = _input_df[["topTeam", "bottomTeam"]].apply(lambda x: search_japan_series(x[0], x[1]), axis=1)
    
    return output_df

# その回何人目のバッターなのかのフラグ
def get_count_batter(input_df):
    output_df = pd.DataFrame()
    
    output_df["count_batter"] = input_df["O"]+input_df["b1"]+input_df["b2"]+input_df["b3"]+1
    
    return output_df

# %%
# encoding系の処理を行う関数
def get_ce_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    
    cols = [
        'pitcher',
        'pitcherHand',
        'batter',
        'batterHand',
        'inning',
        'counts',
        'total_counts',
        'runner_status'
    ]
    
    encoder = CountEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df.astype(str))
    return output_df

def get_oe_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
        #'pitcher',
        'pitcherHand',
        #'batter',
        'batterHand',
        'inning',
        'counts',
        'total_counts',
        'runner_status'
    ]
    encoder = OrdinalEncodingBlock(cols = cols)
    output_df = encoder.fit(_input_df)
    return output_df

def get_ohe_features(input_df):
    _input_df = pd.concat([input_df], axis=1)
    cols = [
       #'pitcher',
        'pitcherHand',
        #'batter',
        'batterHand',
        'inning',
        'counts',
        'total_counts',
        'runner_status'
    ]
    encoder = OneHotEncodingBlock(cols=cols)
    output_df = encoder.fit(_input_df)
    return output_df


# numeric_feature
def create_numeric_feature(input_df):
    use_columns = [
        'totalPitchingCount',
        'B', 'S', 'O','b1', 'b2', 'b3',
    ]

    return input_df[use_columns].copy()

# %%
# 前処理関数を順々に処理していく関数
def to_features(train, test):
    input_df = pd.concat([train, test]).reset_index(drop=True)

    processes = [
        get_oe_features,
        get_ce_features,
        get_ohe_features,
        create_numeric_feature,
        get_inning,
        get_pvsb,
        get_agg_inning,
        get_agg_runner_status,
        get_full_count,
        get_match,
        get_league,
        get_count_batter
    ]

    output_df = pd.DataFrame()
    for func in tqdm(processes):
        _df = func(input_df)
        assert len(_df) == len(input_df), func.__name__
        output_df = pd.concat([output_df, _df], axis=1)

    train_x = output_df.iloc[:len(train)] 
    test_x = output_df.iloc[len(train):].reset_index(drop=True)
    return train_x, test_x

# %%
target_data = "y" 

train_x, test_x = to_features(train_df, test_df)
train_ys_for_split = train_df[target_data]
train_ys = train_df[target_data].values
# Out:
#  17%|█▋        | 2/12 [00:00<00:02,  4.48it/s]/home/kengo-fujii/anaconda3/envs/py36/lib/python3.6/site-packages/category_encoders/utils.py:21: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# 100%|██████████| 12/12 [00:02<00:00,  4.16it/s]

# %%
def fit_lgbm(X, y, cv, params: dict=None, verbose: int=50):
    """lightGBM を CrossValidation の枠組みで学習を行なう function"""
    metric_func = f1_score

    # パラメータがないときは、空の dict で置き換える
    if params is None:
        params = {}

    models = []
    # training data の target と同じだけのゼロ配列を用意
    # float にしないと悲しい事件が起こるのでそこだけ注意
    oof_pred = np.zeros_like(y, dtype=np.float)

    for i, (idx_train, idx_valid) in enumerate(cv): 
        # この部分が交差検証のところです。データセットを cv instance によって分割します
        # training data を trian/valid に分割
        x_train, y_train = X[idx_train], y[idx_train]
        x_valid, y_valid = X[idx_valid], y[idx_valid]

        clf = lgb.LGBMClassifier(**params)

        with timer(prefix='fit fold={} '.format(i + 1)):
            clf.fit(x_train, y_train, 
                    eval_set=[(x_valid, y_valid)],  
                    early_stopping_rounds=verbose,
                    verbose=verbose)

        pred_i = clf.predict(x_valid)

        oof_pred[idx_valid] = pred_i
        models.append(clf)

        print(f'Fold {i} Macro-F1: {metric_func(y_valid, pred_i, average="macro") :.4f}')

    score = metric_func(y, oof_pred, average="macro") 
    print('FINISHED | Whole Macro-F1: {:.4f}'.format(score))
    return oof_pred, models

# %%
lgm_params = {  
    "n_estimators": 20000,
    "objective": 'multiclass',
    "num_class":8,
    "learning_rate": 0.01,
    "num_leaves": 36,
    "random_state": 71,
    "n_jobs": -1,
    "importance_type": "gain",
    'colsample_bytree': .5,
    "reg_lambda": 5,
    "max_depth":7,
    }

fold = StratifiedKFold(n_splits=11, shuffle=True, random_state=71)
cv = list(fold.split(train_x, train_ys)) # もともとが generator なため明示的に list に変換する

# %%
oof, models = fit_lgbm(train_x.values, train_ys, cv, params=lgm_params)
# Out:
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.45975
# [100]	valid_0's multi_logloss: 1.4415
# [150]	valid_0's multi_logloss: 1.43191
# [200]	valid_0's multi_logloss: 1.42579
# [250]	valid_0's multi_logloss: 1.42166
# [300]	valid_0's multi_logloss: 1.41838
# [350]	valid_0's multi_logloss: 1.41567
# [400]	valid_0's multi_logloss: 1.41368
# [450]	valid_0's multi_logloss: 1.41167
# [500]	valid_0's multi_logloss: 1.40924
# [550]	valid_0's multi_logloss: 1.40754
# [600]	valid_0's multi_logloss: 1.40581
# [650]	valid_0's multi_logloss: 1.40393
# [700]	valid_0's multi_logloss: 1.40235
# [750]	valid_0's multi_logloss: 1.40068
# [800]	valid_0's multi_logloss: 1.39958
# [850]	valid_0's multi_logloss: 1.39869
# [900]	valid_0's multi_logloss: 1.39765
# [950]	valid_0's multi_logloss: 1.39665
# [1000]	valid_0's multi_logloss: 1.39576
# [1050]	valid_0's multi_logloss: 1.3948
# [1100]	valid_0's multi_logloss: 1.3939
# [1150]	valid_0's multi_logloss: 1.3929
# [1200]	valid_0's multi_logloss: 1.39172
# [1250]	valid_0's multi_logloss: 1.39075
# [1300]	valid_0's multi_logloss: 1.39057
# [1350]	valid_0's multi_logloss: 1.38987
# [1400]	valid_0's multi_logloss: 1.3896
# [1450]	valid_0's multi_logloss: 1.38904
# [1500]	valid_0's multi_logloss: 1.38857
# [1550]	valid_0's multi_logloss: 1.38805
# [1600]	valid_0's multi_logloss: 1.3876
# [1650]	valid_0's multi_logloss: 1.38712
# [1700]	valid_0's multi_logloss: 1.38651
# [1750]	valid_0's multi_logloss: 1.38592
# [1800]	valid_0's multi_logloss: 1.3855
# [1850]	valid_0's multi_logloss: 1.38477
# [1900]	valid_0's multi_logloss: 1.38382
# [1950]	valid_0's multi_logloss: 1.3832
# [2000]	valid_0's multi_logloss: 1.38277
# [2050]	valid_0's multi_logloss: 1.3824
# [2100]	valid_0's multi_logloss: 1.38186
# [2150]	valid_0's multi_logloss: 1.38153
# [2200]	valid_0's multi_logloss: 1.38137
# [2250]	valid_0's multi_logloss: 1.38114
# [2300]	valid_0's multi_logloss: 1.38088
# [2350]	valid_0's multi_logloss: 1.38057
# [2400]	valid_0's multi_logloss: 1.38018
# [2450]	valid_0's multi_logloss: 1.37985
# [2500]	valid_0's multi_logloss: 1.37965
# [2550]	valid_0's multi_logloss: 1.37934
# [2600]	valid_0's multi_logloss: 1.37913
# [2650]	valid_0's multi_logloss: 1.37889
# [2700]	valid_0's multi_logloss: 1.37866
# [2750]	valid_0's multi_logloss: 1.37846
# [2800]	valid_0's multi_logloss: 1.37814
# [2850]	valid_0's multi_logloss: 1.37782
# [2900]	valid_0's multi_logloss: 1.37757
# [2950]	valid_0's multi_logloss: 1.37742
# [3000]	valid_0's multi_logloss: 1.37752
# Early stopping, best iteration is:
# [2955]	valid_0's multi_logloss: 1.37739
# fit fold=1 35.990[s]
# Fold 0 Macro-F1: 0.3056
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46232
# [100]	valid_0's multi_logloss: 1.44635
# [150]	valid_0's multi_logloss: 1.43804
# [200]	valid_0's multi_logloss: 1.4323
# [250]	valid_0's multi_logloss: 1.42788
# [300]	valid_0's multi_logloss: 1.42505
# [350]	valid_0's multi_logloss: 1.42264
# [400]	valid_0's multi_logloss: 1.42092
# [450]	valid_0's multi_logloss: 1.41886
# [500]	valid_0's multi_logloss: 1.41728
# [550]	valid_0's multi_logloss: 1.41604
# [600]	valid_0's multi_logloss: 1.41489
# [650]	valid_0's multi_logloss: 1.41356
# [700]	valid_0's multi_logloss: 1.41261
# [750]	valid_0's multi_logloss: 1.41186
# [800]	valid_0's multi_logloss: 1.41109
# [850]	valid_0's multi_logloss: 1.41023
# [900]	valid_0's multi_logloss: 1.40935
# [950]	valid_0's multi_logloss: 1.40836
# [1000]	valid_0's multi_logloss: 1.40758
# [1050]	valid_0's multi_logloss: 1.40696
# [1100]	valid_0's multi_logloss: 1.40625
# [1150]	valid_0's multi_logloss: 1.40553
# [1200]	valid_0's multi_logloss: 1.40425
# [1250]	valid_0's multi_logloss: 1.40361
# [1300]	valid_0's multi_logloss: 1.4026
# [1350]	valid_0's multi_logloss: 1.40147
# [1400]	valid_0's multi_logloss: 1.4008
# [1450]	valid_0's multi_logloss: 1.40014
# [1500]	valid_0's multi_logloss: 1.39887
# [1550]	valid_0's multi_logloss: 1.39803
# [1600]	valid_0's multi_logloss: 1.39707
# [1650]	valid_0's multi_logloss: 1.39599
# [1700]	valid_0's multi_logloss: 1.39562
# [1750]	valid_0's multi_logloss: 1.39521
# [1800]	valid_0's multi_logloss: 1.39453
# [1850]	valid_0's multi_logloss: 1.39397
# [1900]	valid_0's multi_logloss: 1.39334
# [1950]	valid_0's multi_logloss: 1.39286
# [2000]	valid_0's multi_logloss: 1.3925
# [2050]	valid_0's multi_logloss: 1.39177
# [2100]	valid_0's multi_logloss: 1.3913
# [2150]	valid_0's multi_logloss: 1.39062
# [2200]	valid_0's multi_logloss: 1.39002
# [2250]	valid_0's multi_logloss: 1.38932
# [2300]	valid_0's multi_logloss: 1.38877
# [2350]	valid_0's multi_logloss: 1.38804
# [2400]	valid_0's multi_logloss: 1.38749
# [2450]	valid_0's multi_logloss: 1.38684
# [2500]	valid_0's multi_logloss: 1.38643
# [2550]	valid_0's multi_logloss: 1.38589
# [2600]	valid_0's multi_logloss: 1.3854
# [2650]	valid_0's multi_logloss: 1.38476
# [2700]	valid_0's multi_logloss: 1.38449
# [2750]	valid_0's multi_logloss: 1.38418
# [2800]	valid_0's multi_logloss: 1.38375
# [2850]	valid_0's multi_logloss: 1.38347
# [2900]	valid_0's multi_logloss: 1.38311
# [2950]	valid_0's multi_logloss: 1.38267
# [3000]	valid_0's multi_logloss: 1.38216
# [3050]	valid_0's multi_logloss: 1.38167
# [3100]	valid_0's multi_logloss: 1.38117
# [3150]	valid_0's multi_logloss: 1.38072
# [3200]	valid_0's multi_logloss: 1.38019
# [3250]	valid_0's multi_logloss: 1.37986
# [3300]	valid_0's multi_logloss: 1.37939
# [3350]	valid_0's multi_logloss: 1.37897
# [3400]	valid_0's multi_logloss: 1.3786
# [3450]	valid_0's multi_logloss: 1.3783
# [3500]	valid_0's multi_logloss: 1.37797
# [3550]	valid_0's multi_logloss: 1.37783
# [3600]	valid_0's multi_logloss: 1.37753
# Early stopping, best iteration is:
# [3577]	valid_0's multi_logloss: 1.37751
# fit fold=2 41.355[s]
# Fold 1 Macro-F1: 0.2977
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46216
# [100]	valid_0's multi_logloss: 1.44616
# [150]	valid_0's multi_logloss: 1.43791
# [200]	valid_0's multi_logloss: 1.43323
# [250]	valid_0's multi_logloss: 1.43002
# [300]	valid_0's multi_logloss: 1.42726
# [350]	valid_0's multi_logloss: 1.42479
# [400]	valid_0's multi_logloss: 1.42267
# [450]	valid_0's multi_logloss: 1.42087
# [500]	valid_0's multi_logloss: 1.41883
# [550]	valid_0's multi_logloss: 1.41727
# [600]	valid_0's multi_logloss: 1.41651
# [650]	valid_0's multi_logloss: 1.41524
# [700]	valid_0's multi_logloss: 1.41368
# [750]	valid_0's multi_logloss: 1.41274
# [800]	valid_0's multi_logloss: 1.41149
# [850]	valid_0's multi_logloss: 1.41021
# [900]	valid_0's multi_logloss: 1.40911
# [950]	valid_0's multi_logloss: 1.40804
# [1000]	valid_0's multi_logloss: 1.40694
# [1050]	valid_0's multi_logloss: 1.40585
# [1100]	valid_0's multi_logloss: 1.40512
# [1150]	valid_0's multi_logloss: 1.4041
# [1200]	valid_0's multi_logloss: 1.40314
# [1250]	valid_0's multi_logloss: 1.40214
# [1300]	valid_0's multi_logloss: 1.40069
# [1350]	valid_0's multi_logloss: 1.39987
# [1400]	valid_0's multi_logloss: 1.39904
# [1450]	valid_0's multi_logloss: 1.39851
# [1500]	valid_0's multi_logloss: 1.39769
# [1550]	valid_0's multi_logloss: 1.39685
# [1600]	valid_0's multi_logloss: 1.39633
# [1650]	valid_0's multi_logloss: 1.39602
# [1700]	valid_0's multi_logloss: 1.39518
# [1750]	valid_0's multi_logloss: 1.39487
# [1800]	valid_0's multi_logloss: 1.39444
# [1850]	valid_0's multi_logloss: 1.39394
# [1900]	valid_0's multi_logloss: 1.39371
# [1950]	valid_0's multi_logloss: 1.39309
# [2000]	valid_0's multi_logloss: 1.39276
# [2050]	valid_0's multi_logloss: 1.39221
# [2100]	valid_0's multi_logloss: 1.39164
# [2150]	valid_0's multi_logloss: 1.3911
# [2200]	valid_0's multi_logloss: 1.39055
# [2250]	valid_0's multi_logloss: 1.38995
# [2300]	valid_0's multi_logloss: 1.38958
# [2350]	valid_0's multi_logloss: 1.38921
# [2400]	valid_0's multi_logloss: 1.38906
# [2450]	valid_0's multi_logloss: 1.38896
# [2500]	valid_0's multi_logloss: 1.38865
# [2550]	valid_0's multi_logloss: 1.38795
# [2600]	valid_0's multi_logloss: 1.38767
# [2650]	valid_0's multi_logloss: 1.38737
# Early stopping, best iteration is:
# [2644]	valid_0's multi_logloss: 1.38729
# fit fold=3 49.762[s]
# Fold 2 Macro-F1: 0.2634
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46227
# [100]	valid_0's multi_logloss: 1.44553
# [150]	valid_0's multi_logloss: 1.43679
# [200]	valid_0's multi_logloss: 1.43158
# [250]	valid_0's multi_logloss: 1.42786
# [300]	valid_0's multi_logloss: 1.42542
# [350]	valid_0's multi_logloss: 1.42349
# [400]	valid_0's multi_logloss: 1.42177
# [450]	valid_0's multi_logloss: 1.42012
# [500]	valid_0's multi_logloss: 1.41887
# [550]	valid_0's multi_logloss: 1.41701
# [600]	valid_0's multi_logloss: 1.41587
# [650]	valid_0's multi_logloss: 1.41462
# [700]	valid_0's multi_logloss: 1.41369
# [750]	valid_0's multi_logloss: 1.41251
# [800]	valid_0's multi_logloss: 1.41114
# [850]	valid_0's multi_logloss: 1.40985
# [900]	valid_0's multi_logloss: 1.40905
# [950]	valid_0's multi_logloss: 1.40824
# [1000]	valid_0's multi_logloss: 1.40724
# [1050]	valid_0's multi_logloss: 1.40664
# [1100]	valid_0's multi_logloss: 1.40568
# [1150]	valid_0's multi_logloss: 1.40497
# [1200]	valid_0's multi_logloss: 1.40404
# [1250]	valid_0's multi_logloss: 1.40322
# [1300]	valid_0's multi_logloss: 1.40229
# [1350]	valid_0's multi_logloss: 1.40146
# [1400]	valid_0's multi_logloss: 1.40079
# [1450]	valid_0's multi_logloss: 1.40031
# [1500]	valid_0's multi_logloss: 1.3993
# [1550]	valid_0's multi_logloss: 1.39834
# [1600]	valid_0's multi_logloss: 1.39757
# [1650]	valid_0's multi_logloss: 1.39688
# [1700]	valid_0's multi_logloss: 1.39645
# [1750]	valid_0's multi_logloss: 1.3956
# [1800]	valid_0's multi_logloss: 1.39469
# [1850]	valid_0's multi_logloss: 1.39411
# [1900]	valid_0's multi_logloss: 1.39354
# [1950]	valid_0's multi_logloss: 1.39288
# [2000]	valid_0's multi_logloss: 1.39238
# [2050]	valid_0's multi_logloss: 1.39197
# [2100]	valid_0's multi_logloss: 1.3914
# [2150]	valid_0's multi_logloss: 1.39069
# [2200]	valid_0's multi_logloss: 1.39006
# [2250]	valid_0's multi_logloss: 1.38976
# [2300]	valid_0's multi_logloss: 1.38891
# [2350]	valid_0's multi_logloss: 1.38822
# [2400]	valid_0's multi_logloss: 1.38784
# [2450]	valid_0's multi_logloss: 1.38774
# Early stopping, best iteration is:
# [2418]	valid_0's multi_logloss: 1.38768
# fit fold=4 32.542[s]
# Fold 3 Macro-F1: 0.2558
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.45724
# [100]	valid_0's multi_logloss: 1.4386
# [150]	valid_0's multi_logloss: 1.42873
# [200]	valid_0's multi_logloss: 1.42254
# [250]	valid_0's multi_logloss: 1.418
# [300]	valid_0's multi_logloss: 1.41455
# [350]	valid_0's multi_logloss: 1.41191
# [400]	valid_0's multi_logloss: 1.40979
# [450]	valid_0's multi_logloss: 1.40798
# [500]	valid_0's multi_logloss: 1.40616
# [550]	valid_0's multi_logloss: 1.4047
# [600]	valid_0's multi_logloss: 1.40311
# [650]	valid_0's multi_logloss: 1.4015
# [700]	valid_0's multi_logloss: 1.40005
# [750]	valid_0's multi_logloss: 1.399
# [800]	valid_0's multi_logloss: 1.39743
# [850]	valid_0's multi_logloss: 1.39599
# [900]	valid_0's multi_logloss: 1.3947
# [950]	valid_0's multi_logloss: 1.39346
# [1000]	valid_0's multi_logloss: 1.39225
# [1050]	valid_0's multi_logloss: 1.39118
# [1100]	valid_0's multi_logloss: 1.38994
# [1150]	valid_0's multi_logloss: 1.38892
# [1200]	valid_0's multi_logloss: 1.3878
# [1250]	valid_0's multi_logloss: 1.38714
# [1300]	valid_0's multi_logloss: 1.38639
# [1350]	valid_0's multi_logloss: 1.38573
# [1400]	valid_0's multi_logloss: 1.38503
# [1450]	valid_0's multi_logloss: 1.38449
# [1500]	valid_0's multi_logloss: 1.38406
# [1550]	valid_0's multi_logloss: 1.38365
# [1600]	valid_0's multi_logloss: 1.38303
# [1650]	valid_0's multi_logloss: 1.38242
# [1700]	valid_0's multi_logloss: 1.38227
# [1750]	valid_0's multi_logloss: 1.382
# [1800]	valid_0's multi_logloss: 1.38133
# [1850]	valid_0's multi_logloss: 1.3806
# [1900]	valid_0's multi_logloss: 1.38021
# [1950]	valid_0's multi_logloss: 1.37955
# [2000]	valid_0's multi_logloss: 1.37898
# [2050]	valid_0's multi_logloss: 1.37858
# [2100]	valid_0's multi_logloss: 1.37797
# [2150]	valid_0's multi_logloss: 1.3773
# [2200]	valid_0's multi_logloss: 1.37665
# [2250]	valid_0's multi_logloss: 1.37609
# [2300]	valid_0's multi_logloss: 1.37553
# [2350]	valid_0's multi_logloss: 1.37493
# [2400]	valid_0's multi_logloss: 1.37449
# [2450]	valid_0's multi_logloss: 1.37388
# [2500]	valid_0's multi_logloss: 1.37336
# [2550]	valid_0's multi_logloss: 1.37287
# [2600]	valid_0's multi_logloss: 1.37239
# [2650]	valid_0's multi_logloss: 1.37183
# [2700]	valid_0's multi_logloss: 1.37154
# [2750]	valid_0's multi_logloss: 1.37121
# [2800]	valid_0's multi_logloss: 1.37083
# [2850]	valid_0's multi_logloss: 1.37066
# [2900]	valid_0's multi_logloss: 1.37015
# [2950]	valid_0's multi_logloss: 1.36975
# [3000]	valid_0's multi_logloss: 1.36938
# [3050]	valid_0's multi_logloss: 1.36933
# [3100]	valid_0's multi_logloss: 1.36936
# [3150]	valid_0's multi_logloss: 1.36897
# [3200]	valid_0's multi_logloss: 1.36881
# [3250]	valid_0's multi_logloss: 1.36875
# [3300]	valid_0's multi_logloss: 1.36857
# [3350]	valid_0's multi_logloss: 1.36851
# [3400]	valid_0's multi_logloss: 1.36814
# [3450]	valid_0's multi_logloss: 1.36798
# [3500]	valid_0's multi_logloss: 1.3676
# [3550]	valid_0's multi_logloss: 1.3674
# [3600]	valid_0's multi_logloss: 1.3672
# Early stopping, best iteration is:
# [3597]	valid_0's multi_logloss: 1.36719
# fit fold=5 46.394[s]
# Fold 4 Macro-F1: 0.3346
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.4624
# [100]	valid_0's multi_logloss: 1.44514
# [150]	valid_0's multi_logloss: 1.43584
# [200]	valid_0's multi_logloss: 1.42932
# [250]	valid_0's multi_logloss: 1.42421
# [300]	valid_0's multi_logloss: 1.42039
# [350]	valid_0's multi_logloss: 1.41723
# [400]	valid_0's multi_logloss: 1.41466
# [450]	valid_0's multi_logloss: 1.41249
# [500]	valid_0's multi_logloss: 1.41085
# [550]	valid_0's multi_logloss: 1.40918
# [600]	valid_0's multi_logloss: 1.40773
# [650]	valid_0's multi_logloss: 1.40576
# [700]	valid_0's multi_logloss: 1.40402
# [750]	valid_0's multi_logloss: 1.40191
# [800]	valid_0's multi_logloss: 1.40024
# [850]	valid_0's multi_logloss: 1.39871
# [900]	valid_0's multi_logloss: 1.39684
# [950]	valid_0's multi_logloss: 1.39516
# [1000]	valid_0's multi_logloss: 1.39388
# [1050]	valid_0's multi_logloss: 1.39243
# [1100]	valid_0's multi_logloss: 1.39103
# [1150]	valid_0's multi_logloss: 1.38903
# [1200]	valid_0's multi_logloss: 1.3874
# [1250]	valid_0's multi_logloss: 1.38619
# [1300]	valid_0's multi_logloss: 1.38493
# [1350]	valid_0's multi_logloss: 1.38325
# [1400]	valid_0's multi_logloss: 1.38169
# [1450]	valid_0's multi_logloss: 1.38066
# [1500]	valid_0's multi_logloss: 1.37924
# [1550]	valid_0's multi_logloss: 1.37793
# [1600]	valid_0's multi_logloss: 1.37656
# [1650]	valid_0's multi_logloss: 1.37546
# [1700]	valid_0's multi_logloss: 1.37433
# [1750]	valid_0's multi_logloss: 1.37329
# [1800]	valid_0's multi_logloss: 1.37257
# [1850]	valid_0's multi_logloss: 1.37149
# [1900]	valid_0's multi_logloss: 1.37058
# [1950]	valid_0's multi_logloss: 1.36971
# [2000]	valid_0's multi_logloss: 1.36884
# [2050]	valid_0's multi_logloss: 1.3679
# [2100]	valid_0's multi_logloss: 1.36716
# [2150]	valid_0's multi_logloss: 1.36624
# [2200]	valid_0's multi_logloss: 1.36575
# [2250]	valid_0's multi_logloss: 1.36512
# [2300]	valid_0's multi_logloss: 1.36449
# [2350]	valid_0's multi_logloss: 1.364
# [2400]	valid_0's multi_logloss: 1.36311
# [2450]	valid_0's multi_logloss: 1.36225
# [2500]	valid_0's multi_logloss: 1.36126
# [2550]	valid_0's multi_logloss: 1.36059
# [2600]	valid_0's multi_logloss: 1.3598
# [2650]	valid_0's multi_logloss: 1.35898
# [2700]	valid_0's multi_logloss: 1.35821
# [2750]	valid_0's multi_logloss: 1.35767
# [2800]	valid_0's multi_logloss: 1.35687
# [2850]	valid_0's multi_logloss: 1.35657
# [2900]	valid_0's multi_logloss: 1.35635
# [2950]	valid_0's multi_logloss: 1.35553
# [3000]	valid_0's multi_logloss: 1.35487
# [3050]	valid_0's multi_logloss: 1.35418
# [3100]	valid_0's multi_logloss: 1.35352
# [3150]	valid_0's multi_logloss: 1.35294
# [3200]	valid_0's multi_logloss: 1.35242
# [3250]	valid_0's multi_logloss: 1.35173
# [3300]	valid_0's multi_logloss: 1.35103
# [3350]	valid_0's multi_logloss: 1.3505
# [3400]	valid_0's multi_logloss: 1.34996
# [3450]	valid_0's multi_logloss: 1.3494
# [3500]	valid_0's multi_logloss: 1.34902
# [3550]	valid_0's multi_logloss: 1.34876
# [3600]	valid_0's multi_logloss: 1.34837
# [3650]	valid_0's multi_logloss: 1.34767
# [3700]	valid_0's multi_logloss: 1.34702
# [3750]	valid_0's multi_logloss: 1.34667
# [3800]	valid_0's multi_logloss: 1.34636
# [3850]	valid_0's multi_logloss: 1.34567
# [3900]	valid_0's multi_logloss: 1.34543
# [3950]	valid_0's multi_logloss: 1.34511
# [4000]	valid_0's multi_logloss: 1.34477
# [4050]	valid_0's multi_logloss: 1.34433
# [4100]	valid_0's multi_logloss: 1.34404
# [4150]	valid_0's multi_logloss: 1.34372
# [4200]	valid_0's multi_logloss: 1.34365
# Early stopping, best iteration is:
# [4159]	valid_0's multi_logloss: 1.34358
# fit fold=6 64.220[s]
# Fold 5 Macro-F1: 0.4973
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.4632
# [100]	valid_0's multi_logloss: 1.44896
# [150]	valid_0's multi_logloss: 1.44221
# [200]	valid_0's multi_logloss: 1.43837
# [250]	valid_0's multi_logloss: 1.43508
# [300]	valid_0's multi_logloss: 1.43197
# [350]	valid_0's multi_logloss: 1.42901
# [400]	valid_0's multi_logloss: 1.42664
# [450]	valid_0's multi_logloss: 1.4247
# [500]	valid_0's multi_logloss: 1.42312
# [550]	valid_0's multi_logloss: 1.42167
# [600]	valid_0's multi_logloss: 1.42054
# [650]	valid_0's multi_logloss: 1.419
# [700]	valid_0's multi_logloss: 1.41786
# [750]	valid_0's multi_logloss: 1.41661
# [800]	valid_0's multi_logloss: 1.41539
# [850]	valid_0's multi_logloss: 1.41398
# [900]	valid_0's multi_logloss: 1.41267
# [950]	valid_0's multi_logloss: 1.41142
# [1000]	valid_0's multi_logloss: 1.41022
# [1050]	valid_0's multi_logloss: 1.40939
# [1100]	valid_0's multi_logloss: 1.4085
# [1150]	valid_0's multi_logloss: 1.40748
# [1200]	valid_0's multi_logloss: 1.40653
# [1250]	valid_0's multi_logloss: 1.40576
# [1300]	valid_0's multi_logloss: 1.40487
# [1350]	valid_0's multi_logloss: 1.40392
# [1400]	valid_0's multi_logloss: 1.4029
# [1450]	valid_0's multi_logloss: 1.40231
# [1500]	valid_0's multi_logloss: 1.40133
# [1550]	valid_0's multi_logloss: 1.40055
# [1600]	valid_0's multi_logloss: 1.3997
# [1650]	valid_0's multi_logloss: 1.39898
# [1700]	valid_0's multi_logloss: 1.39855
# [1750]	valid_0's multi_logloss: 1.39788
# [1800]	valid_0's multi_logloss: 1.3974
# [1850]	valid_0's multi_logloss: 1.39685
# [1900]	valid_0's multi_logloss: 1.39634
# [1950]	valid_0's multi_logloss: 1.39548
# [2000]	valid_0's multi_logloss: 1.39497
# [2050]	valid_0's multi_logloss: 1.39471
# [2100]	valid_0's multi_logloss: 1.39434
# [2150]	valid_0's multi_logloss: 1.39388
# [2200]	valid_0's multi_logloss: 1.39335
# [2250]	valid_0's multi_logloss: 1.39261
# [2300]	valid_0's multi_logloss: 1.39222
# [2350]	valid_0's multi_logloss: 1.39157
# [2400]	valid_0's multi_logloss: 1.39141
# [2450]	valid_0's multi_logloss: 1.39086
# [2500]	valid_0's multi_logloss: 1.39032
# [2550]	valid_0's multi_logloss: 1.39
# [2600]	valid_0's multi_logloss: 1.38974
# [2650]	valid_0's multi_logloss: 1.38927
# [2700]	valid_0's multi_logloss: 1.38884
# [2750]	valid_0's multi_logloss: 1.38876
# [2800]	valid_0's multi_logloss: 1.38825
# [2850]	valid_0's multi_logloss: 1.3878
# [2900]	valid_0's multi_logloss: 1.38712
# [2950]	valid_0's multi_logloss: 1.38661
# [3000]	valid_0's multi_logloss: 1.38602
# [3050]	valid_0's multi_logloss: 1.38533
# [3100]	valid_0's multi_logloss: 1.38481
# [3150]	valid_0's multi_logloss: 1.38445
# [3200]	valid_0's multi_logloss: 1.38392
# [3250]	valid_0's multi_logloss: 1.38359
# [3300]	valid_0's multi_logloss: 1.38334
# [3350]	valid_0's multi_logloss: 1.38326
# [3400]	valid_0's multi_logloss: 1.38323
# [3450]	valid_0's multi_logloss: 1.38303
# [3500]	valid_0's multi_logloss: 1.38249
# [3550]	valid_0's multi_logloss: 1.38199
# [3600]	valid_0's multi_logloss: 1.38144
# [3650]	valid_0's multi_logloss: 1.38146
# [3700]	valid_0's multi_logloss: 1.38116
# [3750]	valid_0's multi_logloss: 1.38089
# [3800]	valid_0's multi_logloss: 1.38062
# [3850]	valid_0's multi_logloss: 1.38026
# [3900]	valid_0's multi_logloss: 1.37962
# [3950]	valid_0's multi_logloss: 1.37925
# [4000]	valid_0's multi_logloss: 1.37922
# [4050]	valid_0's multi_logloss: 1.37897
# [4100]	valid_0's multi_logloss: 1.37891
# [4150]	valid_0's multi_logloss: 1.37881
# Early stopping, best iteration is:
# [4149]	valid_0's multi_logloss: 1.37879
# fit fold=7 50.685[s]
# Fold 6 Macro-F1: 0.3963
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46757
# [100]	valid_0's multi_logloss: 1.45428
# [150]	valid_0's multi_logloss: 1.44817
# [200]	valid_0's multi_logloss: 1.4436
# [250]	valid_0's multi_logloss: 1.44029
# [300]	valid_0's multi_logloss: 1.43737
# [350]	valid_0's multi_logloss: 1.43575
# [400]	valid_0's multi_logloss: 1.43406
# [450]	valid_0's multi_logloss: 1.43273
# [500]	valid_0's multi_logloss: 1.43152
# [550]	valid_0's multi_logloss: 1.43064
# [600]	valid_0's multi_logloss: 1.42952
# [650]	valid_0's multi_logloss: 1.42857
# [700]	valid_0's multi_logloss: 1.4277
# [750]	valid_0's multi_logloss: 1.42669
# [800]	valid_0's multi_logloss: 1.42562
# [850]	valid_0's multi_logloss: 1.42461
# [900]	valid_0's multi_logloss: 1.42357
# [950]	valid_0's multi_logloss: 1.42221
# [1000]	valid_0's multi_logloss: 1.42136
# [1050]	valid_0's multi_logloss: 1.4205
# [1100]	valid_0's multi_logloss: 1.41921
# [1150]	valid_0's multi_logloss: 1.41855
# [1200]	valid_0's multi_logloss: 1.41781
# [1250]	valid_0's multi_logloss: 1.41725
# [1300]	valid_0's multi_logloss: 1.41649
# [1350]	valid_0's multi_logloss: 1.41556
# [1400]	valid_0's multi_logloss: 1.41467
# [1450]	valid_0's multi_logloss: 1.41385
# [1500]	valid_0's multi_logloss: 1.41305
# [1550]	valid_0's multi_logloss: 1.41209
# [1600]	valid_0's multi_logloss: 1.41104
# [1650]	valid_0's multi_logloss: 1.41011
# [1700]	valid_0's multi_logloss: 1.40972
# [1750]	valid_0's multi_logloss: 1.40923
# [1800]	valid_0's multi_logloss: 1.4087
# [1850]	valid_0's multi_logloss: 1.40813
# [1900]	valid_0's multi_logloss: 1.40741
# [1950]	valid_0's multi_logloss: 1.40663
# [2000]	valid_0's multi_logloss: 1.406
# [2050]	valid_0's multi_logloss: 1.40541
# [2100]	valid_0's multi_logloss: 1.40464
# [2150]	valid_0's multi_logloss: 1.40415
# [2200]	valid_0's multi_logloss: 1.40378
# [2250]	valid_0's multi_logloss: 1.40323
# [2300]	valid_0's multi_logloss: 1.40264
# [2350]	valid_0's multi_logloss: 1.4022
# [2400]	valid_0's multi_logloss: 1.40146
# [2450]	valid_0's multi_logloss: 1.40092
# [2500]	valid_0's multi_logloss: 1.40021
# [2550]	valid_0's multi_logloss: 1.39958
# [2600]	valid_0's multi_logloss: 1.39879
# [2650]	valid_0's multi_logloss: 1.39828
# [2700]	valid_0's multi_logloss: 1.39754
# [2750]	valid_0's multi_logloss: 1.39709
# [2800]	valid_0's multi_logloss: 1.39657
# [2850]	valid_0's multi_logloss: 1.39608
# [2900]	valid_0's multi_logloss: 1.39522
# [2950]	valid_0's multi_logloss: 1.39458
# [3000]	valid_0's multi_logloss: 1.39429
# [3050]	valid_0's multi_logloss: 1.39397
# [3100]	valid_0's multi_logloss: 1.39388
# [3150]	valid_0's multi_logloss: 1.39371
# Early stopping, best iteration is:
# [3138]	valid_0's multi_logloss: 1.39367
# fit fold=8 35.155[s]
# Fold 7 Macro-F1: 0.2685
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46315
# [100]	valid_0's multi_logloss: 1.44631
# [150]	valid_0's multi_logloss: 1.43715
# [200]	valid_0's multi_logloss: 1.43069
# [250]	valid_0's multi_logloss: 1.42621
# [300]	valid_0's multi_logloss: 1.42277
# [350]	valid_0's multi_logloss: 1.4201
# [400]	valid_0's multi_logloss: 1.41802
# [450]	valid_0's multi_logloss: 1.41578
# [500]	valid_0's multi_logloss: 1.41462
# [550]	valid_0's multi_logloss: 1.41333
# [600]	valid_0's multi_logloss: 1.41191
# [650]	valid_0's multi_logloss: 1.41035
# [700]	valid_0's multi_logloss: 1.40883
# [750]	valid_0's multi_logloss: 1.40776
# [800]	valid_0's multi_logloss: 1.40628
# [850]	valid_0's multi_logloss: 1.40538
# [900]	valid_0's multi_logloss: 1.40436
# [950]	valid_0's multi_logloss: 1.40343
# [1000]	valid_0's multi_logloss: 1.40281
# [1050]	valid_0's multi_logloss: 1.40225
# [1100]	valid_0's multi_logloss: 1.40157
# [1150]	valid_0's multi_logloss: 1.40067
# [1200]	valid_0's multi_logloss: 1.39991
# [1250]	valid_0's multi_logloss: 1.39919
# [1300]	valid_0's multi_logloss: 1.39848
# [1350]	valid_0's multi_logloss: 1.39763
# [1400]	valid_0's multi_logloss: 1.39712
# [1450]	valid_0's multi_logloss: 1.39651
# [1500]	valid_0's multi_logloss: 1.39564
# [1550]	valid_0's multi_logloss: 1.39489
# [1600]	valid_0's multi_logloss: 1.39439
# [1650]	valid_0's multi_logloss: 1.39412
# [1700]	valid_0's multi_logloss: 1.39316
# [1750]	valid_0's multi_logloss: 1.39279
# [1800]	valid_0's multi_logloss: 1.39246
# [1850]	valid_0's multi_logloss: 1.39196
# [1900]	valid_0's multi_logloss: 1.3919
# [1950]	valid_0's multi_logloss: 1.39131
# [2000]	valid_0's multi_logloss: 1.39081
# [2050]	valid_0's multi_logloss: 1.39024
# [2100]	valid_0's multi_logloss: 1.39006
# [2150]	valid_0's multi_logloss: 1.38968
# [2200]	valid_0's multi_logloss: 1.38917
# [2250]	valid_0's multi_logloss: 1.38876
# [2300]	valid_0's multi_logloss: 1.38816
# [2350]	valid_0's multi_logloss: 1.38777
# [2400]	valid_0's multi_logloss: 1.38741
# [2450]	valid_0's multi_logloss: 1.38709
# [2500]	valid_0's multi_logloss: 1.38661
# [2550]	valid_0's multi_logloss: 1.38616
# [2600]	valid_0's multi_logloss: 1.38573
# [2650]	valid_0's multi_logloss: 1.3854
# [2700]	valid_0's multi_logloss: 1.38502
# [2750]	valid_0's multi_logloss: 1.3846
# [2800]	valid_0's multi_logloss: 1.38444
# [2850]	valid_0's multi_logloss: 1.38405
# [2900]	valid_0's multi_logloss: 1.38379
# [2950]	valid_0's multi_logloss: 1.3837
# [3000]	valid_0's multi_logloss: 1.38316
# [3050]	valid_0's multi_logloss: 1.3828
# [3100]	valid_0's multi_logloss: 1.38269
# [3150]	valid_0's multi_logloss: 1.38269
# Early stopping, best iteration is:
# [3112]	valid_0's multi_logloss: 1.38256
# fit fold=9 28.626[s]
# Fold 8 Macro-F1: 0.3308
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.46278
# [100]	valid_0's multi_logloss: 1.44637
# [150]	valid_0's multi_logloss: 1.4381
# [200]	valid_0's multi_logloss: 1.43344
# [250]	valid_0's multi_logloss: 1.42985
# [300]	valid_0's multi_logloss: 1.42699
# [350]	valid_0's multi_logloss: 1.42527
# [400]	valid_0's multi_logloss: 1.42363
# [450]	valid_0's multi_logloss: 1.42225
# [500]	valid_0's multi_logloss: 1.42086
# [550]	valid_0's multi_logloss: 1.41937
# [600]	valid_0's multi_logloss: 1.41866
# [650]	valid_0's multi_logloss: 1.41834
# [700]	valid_0's multi_logloss: 1.41725
# [750]	valid_0's multi_logloss: 1.41679
# [800]	valid_0's multi_logloss: 1.41574
# [850]	valid_0's multi_logloss: 1.41513
# [900]	valid_0's multi_logloss: 1.41446
# [950]	valid_0's multi_logloss: 1.41362
# [1000]	valid_0's multi_logloss: 1.41288
# [1050]	valid_0's multi_logloss: 1.41205
# [1100]	valid_0's multi_logloss: 1.41145
# [1150]	valid_0's multi_logloss: 1.41088
# [1200]	valid_0's multi_logloss: 1.40987
# [1250]	valid_0's multi_logloss: 1.40914
# [1300]	valid_0's multi_logloss: 1.40811
# [1350]	valid_0's multi_logloss: 1.40743
# [1400]	valid_0's multi_logloss: 1.4067
# [1450]	valid_0's multi_logloss: 1.40608
# [1500]	valid_0's multi_logloss: 1.40555
# [1550]	valid_0's multi_logloss: 1.40522
# [1600]	valid_0's multi_logloss: 1.40458
# [1650]	valid_0's multi_logloss: 1.40392
# [1700]	valid_0's multi_logloss: 1.40353
# [1750]	valid_0's multi_logloss: 1.40325
# [1800]	valid_0's multi_logloss: 1.40318
# [1850]	valid_0's multi_logloss: 1.40279
# [1900]	valid_0's multi_logloss: 1.40237
# [1950]	valid_0's multi_logloss: 1.40181
# [2000]	valid_0's multi_logloss: 1.40142
# [2050]	valid_0's multi_logloss: 1.40112
# [2100]	valid_0's multi_logloss: 1.40082
# [2150]	valid_0's multi_logloss: 1.4004
# [2200]	valid_0's multi_logloss: 1.40019
# [2250]	valid_0's multi_logloss: 1.39981
# [2300]	valid_0's multi_logloss: 1.39931
# [2350]	valid_0's multi_logloss: 1.399
# [2400]	valid_0's multi_logloss: 1.39893
# [2450]	valid_0's multi_logloss: 1.39883
# Early stopping, best iteration is:
# [2415]	valid_0's multi_logloss: 1.39874
# fit fold=10 19.925[s]
# Fold 9 Macro-F1: 0.2624
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's multi_logloss: 1.47027
# [100]	valid_0's multi_logloss: 1.45921
# [150]	valid_0's multi_logloss: 1.45393
# [200]	valid_0's multi_logloss: 1.4502
# [250]	valid_0's multi_logloss: 1.44761
# [300]	valid_0's multi_logloss: 1.44547
# [350]	valid_0's multi_logloss: 1.4442
# [400]	valid_0's multi_logloss: 1.44302
# [450]	valid_0's multi_logloss: 1.44212
# [500]	valid_0's multi_logloss: 1.44089
# [550]	valid_0's multi_logloss: 1.44017
# [600]	valid_0's multi_logloss: 1.43942
# [650]	valid_0's multi_logloss: 1.43866
# [700]	valid_0's multi_logloss: 1.43774
# [750]	valid_0's multi_logloss: 1.43692
# [800]	valid_0's multi_logloss: 1.43604
# [850]	valid_0's multi_logloss: 1.43508
# [900]	valid_0's multi_logloss: 1.43434
# [950]	valid_0's multi_logloss: 1.43367
# [1000]	valid_0's multi_logloss: 1.43294
# [1050]	valid_0's multi_logloss: 1.43203
# [1100]	valid_0's multi_logloss: 1.43115
# [1150]	valid_0's multi_logloss: 1.42991
# [1200]	valid_0's multi_logloss: 1.42814
# [1250]	valid_0's multi_logloss: 1.42704
# [1300]	valid_0's multi_logloss: 1.42603
# [1350]	valid_0's multi_logloss: 1.42477
# [1400]	valid_0's multi_logloss: 1.42403
# [1450]	valid_0's multi_logloss: 1.42297
# [1500]	valid_0's multi_logloss: 1.42213
# [1550]	valid_0's multi_logloss: 1.42116
# [1600]	valid_0's multi_logloss: 1.42054
# [1650]	valid_0's multi_logloss: 1.41948
# [1700]	valid_0's multi_logloss: 1.41835
# [1750]	valid_0's multi_logloss: 1.41772
# [1800]	valid_0's multi_logloss: 1.4169
# [1850]	valid_0's multi_logloss: 1.41603
# [1900]	valid_0's multi_logloss: 1.41517
# [1950]	valid_0's multi_logloss: 1.41408
# [2000]	valid_0's multi_logloss: 1.41318
# [2050]	valid_0's multi_logloss: 1.41227
# [2100]	valid_0's multi_logloss: 1.41147
# [2150]	valid_0's multi_logloss: 1.41109
# [2200]	valid_0's multi_logloss: 1.41042
# [2250]	valid_0's multi_logloss: 1.40999
# [2300]	valid_0's multi_logloss: 1.40928
# [2350]	valid_0's multi_logloss: 1.40898
# [2400]	valid_0's multi_logloss: 1.40864
# [2450]	valid_0's multi_logloss: 1.40786
# [2500]	valid_0's multi_logloss: 1.40703
# [2550]	valid_0's multi_logloss: 1.40639
# [2600]	valid_0's multi_logloss: 1.40573
# [2650]	valid_0's multi_logloss: 1.40526
# [2700]	valid_0's multi_logloss: 1.4046
# [2750]	valid_0's multi_logloss: 1.40386
# [2800]	valid_0's multi_logloss: 1.40345
# [2850]	valid_0's multi_logloss: 1.40281
# [2900]	valid_0's multi_logloss: 1.40237
# [2950]	valid_0's multi_logloss: 1.40193
# [3000]	valid_0's multi_logloss: 1.40104
# [3050]	valid_0's multi_logloss: 1.40036
# [3100]	valid_0's multi_logloss: 1.39983
# [3150]	valid_0's multi_logloss: 1.39936
# [3200]	valid_0's multi_logloss: 1.39898
# [3250]	valid_0's multi_logloss: 1.39847
# [3300]	valid_0's multi_logloss: 1.39787
# [3350]	valid_0's multi_logloss: 1.39749
# [3400]	valid_0's multi_logloss: 1.39703
# [3450]	valid_0's multi_logloss: 1.39653
# [3500]	valid_0's multi_logloss: 1.39611
# [3550]	valid_0's multi_logloss: 1.39549
# [3600]	valid_0's multi_logloss: 1.39501
# [3650]	valid_0's multi_logloss: 1.39475
# [3700]	valid_0's multi_logloss: 1.39458
# [3750]	valid_0's multi_logloss: 1.39446
# [3800]	valid_0's multi_logloss: 1.39448
# Early stopping, best iteration is:
# [3777]	valid_0's multi_logloss: 1.39435
# fit fold=11 43.911[s]
# Fold 10 Macro-F1: 0.3411
# FINISHED | Whole Macro-F1: 0.3401

# %%
def visualize_importance(models, feat_train_df):
    """lightGBM の model 配列の feature importance を plot する
    CVごとのブレを boxen plot として表現します.

    args:
        models:
            List of lightGBM models
        feat_train_df:
            学習時に使った DataFrame
    """
    feature_importance_df = pd.DataFrame()
    for i, model in enumerate(models):
        _df = pd.DataFrame()
        _df['feature_importance'] = model.feature_importances_
        _df['column'] = feat_train_df.columns
        _df['fold'] = i + 1
        feature_importance_df = pd.concat([feature_importance_df, _df], axis=0, ignore_index=True)

    order = feature_importance_df.groupby('column')\
        .sum()[['feature_importance']]\
        .sort_values('feature_importance', ascending=False).index[:50]

    fig, ax = plt.subplots(figsize=(max(6, len(order) * .4), 7))
    sns.boxenplot(data=feature_importance_df, x='column', y='feature_importance', order=order, ax=ax, palette='viridis')
    ax.tick_params(axis='x', rotation=90)
    ax.grid()
    fig.tight_layout()
    return fig, ax

# %%
fig, ax = visualize_importance(models, train_x)

# %%
pred_lgb = np.array([model.predict(test_x.values) for model in models])

# %%
from scipy.stats import mode
pred_lgbs = mode(pred_lgb)[0][0]

# %%
submit_df = pd.DataFrame({'y': pred_lgbs})
submit_df.index.name = 'id'
submit_df.to_csv(emp+'submission.csv')

# %%
np.unique(mode(pred_lgb)[0][0])
# Out:
# array([0, 1, 2, 3, 4, 5, 7])
